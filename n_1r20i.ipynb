# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import n_1rxi as method
import plot_utils

# %%
chunk_size = 20

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size))
fname
# Out:
# 'n_1r20i'

# %%
import rate
rate.setkey(1)

# %%
source = annotate.get_clean()

# %%
test = pd.concat([source[source['Question id'] == 0][:20], source[source['Question id'] == 1][:20]])
test.sort_index(inplace=True)
test
# Out:
#      Participant #            Test_Date  Question id Question_en Answer
# 0               10  2021-12-23T04:04:27            0       Brick     粉砕  \
# 30              11  2022-01-18T06:31:14            0       Brick   フォーク
# 31              11  2022-01-18T06:31:14            1    Umbrella   ラケット
# 90              13  2022-01-27T06:54:05            0       Brick    火打石
# 120             14  2022-02-01T07:09:40            0       Brick     隠蔽
# 150             15  2022-02-03T03:16:53            0       Brick     延長
# 180             16  2022-02-17T02:55:14            0       Brick     寝具
# 210             17  2022-02-22T03:24:46            0       Brick     飲む
# 211             17  2022-02-22T03:24:46            1    Umbrella    たたく
# 240             18  2022-02-24T04:21:52            0       Brick    積み木
# 300             20  2022-03-03T02:59:05            0       Brick    トイレ
# 301             20  2022-03-03T02:59:05            1    Umbrella    バッグ
# 330             21  2022-03-08T07:26:56            0       Brick     巻く
# 331             21  2022-03-08T07:26:56            1    Umbrella    燃やす
# 361             22  2022-03-14T02:53:03            1    Umbrella    浴びる
# 390             23  2022-03-17T02:57:51            0       Brick     殴る
# 391             23  2022-03-17T02:57:51            1    Umbrella   振り回す
# 450             25  2022-03-24T07:11:40            0       Brick      靴
# 481             26  2022-03-29T04:09:38            1    Umbrella      杖
# 510             27  2022-03-31T06:32:49            0       Brick      盾
# 570             29  2022-04-07T07:17:56            0       Brick  つけもの石
# 571             29  2022-04-07T07:17:56            1    Umbrella   プロペラ
# 600             30  2022-04-12T03:29:12            0       Brick     筋肉
# 601             30  2022-04-12T03:29:12            1    Umbrella     武器
# 631             31  2022-04-14T03:20:13            1    Umbrella    バケツ
# 661             32  2022-04-19T03:30:59            1    Umbrella     水瓶
# 690             33  2022-04-21T06:04:00            0       Brick    かばん
# 691             33  2022-04-21T06:04:00            1    Umbrella      袋
# 721             34  2022-04-25T06:58:49            1    Umbrella     突く
# 750             35  2022-05-10T03:26:20            0       Brick     手帳
# 751             35  2022-05-10T03:26:20            1    Umbrella   チョーク
# 780             36  2022-05-19T03:52:15            0       Brick    絵の具
# 781             36  2022-05-19T03:52:15            1    Umbrella      船
# 810             37  2022-05-26T03:25:19            0       Brick   ジェンガ
# 811             37  2022-05-26T03:25:19            1    Umbrella    ゴルフ
# 840             38  2022-05-31T07:21:32            0       Brick    漬物石
# 901             40  2022-06-07T06:58:04            1    Umbrella     つえ
# 931             41  2022-06-14T02:54:58            1    Umbrella    バット
# 961             42  2022-06-16T02:49:14            1    Umbrella    鉢植え
# 991             43  2022-09-26T03:43:31            1    Umbrella    乗り物
#
#      Novelty  Feasibility  Value  W_Novelty  L_Novelty  ...  NG_FEASIBILITY
# 0       1591         1609   1559          7          8  ...               0  \
# 30      1616         1576   1551          9          7  ...               0
# 31      1593         1599   1608          8          9  ...               1
# 90      1608         1585   1608          9          8  ...               0
# 120     1618         1585   1569          9          7  ...               0
# 150     1623         1576   1584         10          7  ...               0
# 180     1640         1548   1606         11          6  ...               1
# 210     1616         1496   1514          9          7  ...               4
# 211     1570         1625   1584          7         11  ...               5
# 240     1521         1638   1552          4         14  ...               0
# 300     1648         1585   1629         11          5  ...               1
# 301     1615         1568   1590         12         10  ...               0
# 330     1635         1528   1552         11          7  ...               1
# 331     1608         1569   1568          9          8  ...               0
# 361     1623         1592   1524         10          7  ...               0
# 390     1553         1616   1568          5         11  ...               0
# 391     1542         1618   1561          6         13  ...               0
# 450     1655         1575   1609         12          5  ...               0
# 481     1542         1680   1640          6         13  ...               0
# 510     1600         1607   1608          8          8  ...               0
# 570     1560         1631   1576          6         11  ...               1
# 571     1656         1558   1672         13          6  ...               0
# 600     1714         1538   1617         16          1  ...               3
# 601     1536         1638   1632          5         13  ...               0
# 631     1591         1593   1582          8          9  ...               1
# 661     1615         1568   1614         10          8  ...               0
# 690     1632         1567   1616         10          6  ...               0
# 691     1631         1571   1576         11          7  ...               0
# 721     1549         1655   1600          6         12  ...               0
# 750     1639         1551   1576         11          6  ...               1
# 751     1687         1560   1521         14          3  ...               2
# 780     1655         1584   1559         12          5  ...               0
# 781     1670         1591   1647         13          4  ...               0
# 810     1571         1592   1625          7         11  ...               1
# 811     1591         1616   1616          8          9  ...               0
# 840     1554         1663   1609          5         11  ...               0
# 901     1469         1691   1591          0         18  ...               1
# 931     1576         1616   1599          7         10  ...               1
# 961     1609         1552   1615          9          8  ...               1
# 991     1647         1544   1616         11          5  ...               0
#
#      NG_VALUE   English  Question  sample_for_novelty  sample_for_feasibility
# 0           5     Brick       レンガ               False                   False  \
# 30          9     Brick       レンガ               False                   False
# 31          6  Umbrella         傘               False                   False
# 90          6     Brick       レンガ               False                   False
# 120         6     Brick       レンガ               False                   False
# 150         3     Brick       レンガ               False                   False
# 180         6     Brick       レンガ               False                   False
# 210         4     Brick       レンガ               False                   False
# 211         7  Umbrella         傘               False                   False
# 240        11     Brick       レンガ               False                   False
# 300         5     Brick       レンガ               False                   False
# 301         8  Umbrella         傘               False                   False
# 330         7     Brick       レンガ               False                   False
# 331         6  Umbrella         傘               False                   False
# 361         8  Umbrella         傘               False                   False
# 390         9     Brick       レンガ               False                   False
# 391         7  Umbrella         傘               False                   False
# 450         7     Brick       レンガ               False                   False
# 481         9  Umbrella         傘               False                   False
# 510         4     Brick       レンガ               False                   False
# 570         8     Brick       レンガ               False                   False
# 571         4  Umbrella         傘               False                   False
# 600         9     Brick       レンガ               False                   False
# 601         9  Umbrella         傘               False                   False
# 631         7  Umbrella         傘               False                   False
# 661         6  Umbrella         傘               False                   False
# 690         7     Brick       レンガ               False                   False
# 691        11  Umbrella         傘               False                   False
# 721         3  Umbrella         傘               False                   False
# 750         6     Brick       レンガ               False                   False
# 751         6  Umbrella         傘               False                   False
# 780         8     Brick       レンガ               False                   False
# 781         0  Umbrella         傘               False                   False
# 810         5     Brick       レンガ               False                   False
# 811         4  Umbrella         傘               False                   False
# 840         3     Brick       レンガ               False                   False
# 901         4  Umbrella         傘               False                   False
# 931         7  Umbrella         傘               False                   False
# 961         4  Umbrella         傘               False                   False
# 991         5  Umbrella         傘               False                   False
#
#      sample_for_value novelty_transformed feasibility_transformed
# 0               False                  52                      52  \
# 30              False                  61                      40
# 31              False                  53                      48
# 90              False                  58                      43
# 120             False                  62                      43
# 150             False                  64                      40
# 180             False                  70                      29
# 210             False                  61                      10
# 211             False                  44                      58
# 240             False                  26                      63
# 300             False                  73                      43
# 301             False                  61                      37
# 330             False                  68                      22
# 331             False                  58                      37
# 361             False                  64                      46
# 390             False                  38                      55
# 391             False                  34                      55
# 450             False                  76                      39
# 481             False                  34                      78
# 510             False                  55                      51
# 570             False                  40                      60
# 571             False                  76                      33
# 600             False                  98                      26
# 601             False                  31                      63
# 631             False                  52                      46
# 661             False                  61                      37
# 690             False                  67                      36
# 691             False                  67                      38
# 721             False                  36                      69
# 750             False                  70                      30
# 751             False                  88                      34
# 780             False                  76                      43
# 781             False                  81                      45
# 810             False                  44                      46
# 811             False                  52                      55
# 840             False                  38                      72
# 901             False                   6                      83
# 931             False                  46                      55
# 961             False                  59                      31
# 991             False                  73                      28
#
#      value_transformed
# 0                   33
# 30                  29
# 31                  56
# 90                  56
# 120                 37
# 150                 45
# 180                 55
# 210                 11
# 211                 45
# 240                 29
# 300                 66
# 301                 47
# 330                 29
# 331                 37
# 361                 16
# 390                 37
# 391                 34
# 450                 56
# 481                 71
# 510                 56
# 570                 41
# 571                 87
# 600                 60
# 601                 67
# 631                 44
# 661                 59
# 690                 60
# 691                 41
# 721                 52
# 750                 41
# 751                 14
# 780                 33
# 781                 75
# 810                 64
# 811                 60
# 840                 56
# 901                 48
# 931                 52
# 961                 59
# 991                 60
#
# [40 rows x 25 columns]

# %%
await method.rate(test)
# Out:
# Request 1 of 6
# Request 2 of 6
# Request 3 of 6
# Request 4 of 6
# Request 5 of 6
# Request 6 of 6

# %%
for expl in test['novelty_explanation']:
    print(expl)
# Out:
# This is a somewhat novel idea, as bricks are usually used for construction, not for being crushed into powder.
# This is a highly novel idea, as bricks are not typically associated with eating utensils.
# Comparing to other unconventional uses, using an umbrella as a racket is not very novel as it's a common makeshift solution when a real racket is not available.
# This is a moderately novel idea, as bricks are not typically used for starting fires, but the concept of striking hard objects together to create sparks is not new.
# This is not a very novel idea, as bricks are often used to build walls and other structures that can serve as hiding places.
# This is a moderately novel idea, as bricks are typically used for building, but not often thought of as a means of extension.
# This is a highly novel idea, as bricks are not typically associated with comfort or sleep.
# This is an extremely novel idea, as bricks are not typically associated with consumption or hydration.
# This is not a very novel idea as umbrellas are often used in this way in a playful or defensive context.
# This is not a novel idea, as bricks are commonly used as building blocks in construction.
# This is a highly novel idea, as bricks are not typically associated with sanitation or bathroom facilities.
# This is a somewhat novel idea, as it's not common to use an umbrella as a bag, but it's feasible due to its shape.
# This is a moderately novel idea, as bricks are not typically wrapped, but the concept of wrapping objects is not new.
# This is a novel idea as it's not common to burn an umbrella, but it's not a positive or constructive use.
# This is a very novel idea as it's not common or practical to bathe with an umbrella.
# This is not a very novel idea, as bricks have been used as weapons or for causing damage in the past.
# This is not a very novel idea as it's a common playful action with an umbrella.
# This is a highly novel idea, as bricks are not typically associated with footwear.
# This is not a very novel idea as it's a common makeshift solution when a real cane is not available.
# This is a moderately novel idea, as bricks are not typically used for personal defense, but they are used to build defensive structures.
# This is a moderately novel idea, as bricks are not typically used in food preparation, but the concept of using heavy objects in pickling is not new.
# This is a very novel idea as it's not common or practical to use an umbrella as a propeller.
# This is an extremely novel idea, as bricks are not typically associated with the human body or its functions.
# This is not a very novel idea as it's a common trope in movies and literature.
# This is a somewhat novel idea, as it's not common to use an umbrella as a bucket, but it's feasible due to its shape.
# This is a very novel idea as it's not common or practical to use an umbrella as a water bottle.
# This is a highly novel idea, as bricks are not typically associated with storage or transportation of items.
# This is a somewhat novel idea, as it's not common to use an umbrella as a bag, but it's feasible due to its shape.
# This is not a very novel idea as it's a common action with an umbrella.
# This is a highly novel idea, as bricks are not typically associated with writing or record keeping.
# This is a very novel idea as it's not common or practical to use an umbrella as a chalk.
# This is a highly novel idea, as bricks are not typically associated with art or color application.
# This is a very novel idea as it's not common or practical to use an umbrella as a boat.
# This is a moderately novel idea, as bricks are similar in shape to Jenga pieces, but are not typically used in games due to their weight and hardness.
# This is a somewhat novel idea, as it's not common to use an umbrella to play golf, but it's feasible due to its shape.
# This is a moderately novel idea, as bricks are not typically used in food preparation, but the concept of using heavy objects in pickling is not new.
# This is not a very novel idea as it's a common makeshift solution when a real cane is not available.
# This is not a very novel idea as it's a common makeshift solution when a real bat is not available.
# This is a very novel idea as it's not common or practical to use an umbrella as a plant pot.
# This is a very novel idea as it's not common or practical to use an umbrella as a vehicle.

# %%
# Shuffle, because GPT is a fucking dickhead and implicitly refuses to rate two similar adjacent answers (case in point: brick as 重石 and 文鎮)
source = source.sample(frac=1, random_state=8)

# %%
await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 243
# Request 2 of 243
# Request 3 of 243
# Request 4 of 243
# Request 5 of 243
# Request 6 of 243
# Request 7 of 243
# Request 8 of 243
# Request 9 of 243
# Request 10 of 243
# Request 11 of 243
# Request 12 of 243
# Request 13 of 243
# Request 14 of 243
# Request 15 of 243
# Request 16 of 243
# Request 17 of 243
# Request 18 of 243
# Request 19 of 243
# Request 20 of 243
# Request 21 of 243
# Request 22 of 243
# Request 23 of 243
# Request 24 of 243
# Request 25 of 243
# Request 26 of 243
# Request 27 of 243
# Request 28 of 243
# Request 29 of 243
# Request 30 of 243
# Request 31 of 243
# Request 32 of 243
# Request 33 of 243
# Request 34 of 243
# Request 35 of 243
# Request 36 of 243
# Request 37 of 243
# Request 38 of 243
# Request 39 of 243
# Request 40 of 243
# Request 41 of 243
# Request 42 of 243
# Request 43 of 243
# Request 44 of 243
# Request 45 of 243
# Request 46 of 243
# Request 47 of 243
# Request 48 of 243
# Request 49 of 243
# Request 50 of 243
# Request 51 of 243
# Request 52 of 243
# Request 53 of 243
# Request 54 of 243
# Request 55 of 243
# Request 56 of 243
# Request 57 of 243
# Request 58 of 243
# Request 59 of 243
# Request 60 of 243
# Request 61 of 243
# Request 62 of 243
# Request 63 of 243
# Request 64 of 243
# Request 65 of 243
# Request 66 of 243
# Request 67 of 243
# Request 68 of 243
# Request 69 of 243
# Request 70 of 243
# Request 71 of 243
# Request 72 of 243
# Request 73 of 243
# Request 74 of 243
# Request 75 of 243
# Request 76 of 243
# Request 77 of 243
# Request 78 of 243
# Request 79 of 243
# Request 80 of 243
# Request 81 of 243
# Request 82 of 243
# Request 83 of 243
# Request 84 of 243
# Request 85 of 243
# Request 86 of 243
# Request 87 of 243
# Request 88 of 243
# Request 89 of 243
# Request 90 of 243
# Request 91 of 243
# Request 92 of 243
# Request 93 of 243
# Request 94 of 243
# Request 95 of 243
# Request 96 of 243
# Request 97 of 243
# Request 98 of 243
# Request 99 of 243
# Request 100 of 243
# Request 101 of 243
# Request 102 of 243
# Request 103 of 243
# Request 104 of 243
# Request 105 of 243
# Request 106 of 243
# Request 107 of 243
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 20 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "テープ" in the following ways:
# 1. 鼻をかむ
# 2. かつら
# 3. 丸めたボール
# 4. 殺す
# 5. ばんそうこう
# 6. 衣装
# 7. 輪投げ
# 8. カーテン
# 9. アクセサリー
# 10. 食べもの
# 11. 命綱
# 12. ぼかし
# 13. 口をふさぐ布
# 14. 止血材
# 15. スプーン
# 16. ラップ
# 17. 投下
# 18. ふせん
# 19. 乗り物
# 20. ヘアアレンジ'''
# Response:
# '''1. テープを使って鼻をかむ
# 鼻をかむためにはティッシュやハンカチが一般的に使用され、これらの商品は比較的安価である。
# {"value":50}
#
# 2. テープをかつらとして使用
# 市販のかつらは数千円から数万円で販売されており、テープで作ったかつらの価値は低いと考えられる。
# {"value":500}
#
# 3. テープを丸めてボールとして使用
# 市場には様々な安価なボールが存在し、テープで作ったボールの商業価値は限定的である。
# {"value":100}
#
# 4. テープを使って殺す（このアイデアは評価しない）
#
# 5. テープをばんそうこうとして使用
# 市販のばんそうこうは非常に安価で広く利用されており、テープを代用品として使用する価値は低い。
# {"value":30}
#
# 6. テープを衣装として使用
# オリジナリティのある衣装として一定の需要はあるかもしれないが、市販の衣装と比較して高価にはなりにくい。
# {"value":2000}
#
# 7. テープを輪投げの輪として使用
# 輪投げの輪は一般的に安価であり、テープを使用した場合の価値は低いと考えられる。
# {"value":150}
#
# 8. テープをカーテンとして使用
# 市販のカーテンは様々な価格帯があり、テープで作ったカーテンは非常にユニークだが、市場価値は限定的。
# {"value":1000}
#
# 9. テープをアクセサリーとして使用
# 手作りアクセサリーの市場はあるが、テープを主材料としたアクセサリーの価値は低めである。
# {"value":500}
#
# 10. テープを食べものとして使用（このアイデアは評価しない）
#
# 11. テープを命綱として使用
# 安全装置としての命綱は高い安全基準が求められ、テープで作った命綱の商業価値は非常に低い。
# {"value":100}
#
# 12. テープをぼかしとして使用
# アート用品としてのぼかしは特定のニーズを満たすが、テープを使用したぼかしの価値は限定的。
# {"value":300}
#
# 13. テープを口をふさぐ布として使用
# 安全やプライバシーに関わる用途での使用は推奨されないため、この用途の商業価値は評価しない。
#
# 14. テープを止血材として使用
# 医療用品としての止血材は特定の基準と認証が必要であり、テープで作った止血材の価値は非常に低い。
# {"value":50}
#
# 15. テープをスプーンとして使用
# 市販のスプーンは非常に安価であり、テープで作ったスプーンの商業価値はほとんどない。
# {"value":20}
#
# 16. テープをラップとして使用
# 食品を包むためのラップは特定の衛生基準を満たす必要があり、テープで作ったラップの価値は低い。
# {"value":50}
#
# 17. テープを投下として使用
# この用途は不明瞭であり、具体的な市場価値を評価することは困難である。
#
# 18. テープをふせんとして使用
# 市販のふせんは非常に安価であり、テープで作ったふせんの商業価値は限定的である。
# {"value":100}
#
# 19. テープを乗り物として使用（このアイデアは評価しない）
#
# 20. テープをヘアアレンジとして使用
# ヘアアクセサリーとしての需要はあるが、テープを使用したヘアアレンジの市場価値は比較的低い。
# {"value":700}'''
# Error: Unexpected number of lines for item 3.
# Retrying request 99 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 108 of 243
# Request 109 of 243
# Request 110 of 243
# Request 111 of 243
# Request 112 of 243
# Request 113 of 243
# Request 114 of 243
# Request 115 of 243
# Request 116 of 243
# Request 117 of 243
# Request 118 of 243
# Request 119 of 243
# Request 120 of 243
# Request 121 of 243
# Request 122 of 243
# Request 123 of 243
# Request 124 of 243
# Request 125 of 243
# Request 126 of 243
# Request 127 of 243
# Request 128 of 243
# Request 129 of 243
# Request 130 of 243
# Request 131 of 243
# Request 132 of 243
# Request 133 of 243
# Request 134 of 243
# Request 135 of 243
# Request 136 of 243
# Request 137 of 243
# Request 138 of 243
# Request 139 of 243
# Request 140 of 243
# Request 141 of 243
# Request 142 of 243
# Request 143 of 243
# Request 144 of 243
# Request 145 of 243
# Request 146 of 243
# Request 147 of 243
# Request 148 of 243
# Request 149 of 243
# Request 150 of 243
# Request 151 of 243
# Request 152 of 243
# Failed parse (chunk 2). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 20 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "虫眼鏡" in the following ways:
# 1. コンロ
# 2. 火起こし器
# 3. ライター
# 4. 栞
# 5. 残す
# 6. 万華鏡
# 7. インテリア
# 8. カーテン
# 9. 文鎮
# 10. 集光器
# 11. 望遠鏡
# 12. ハエたたき
# 13. プリズム
# 14. コンパス
# 15. 調理器具
# 16. 双眼鏡
# 17. 器
# 18. 火おこし
# 19. テレビ
# 20. 武器'''
# Response:
# '''1. コンロとしての使用
# 虫眼鏡を太陽光を集めて料理をするコンロとして使用するアイデア。市場には太陽光を利用するコンロが既に存在し、一定の需要がある。
# {"value":5000}
#
# 2. 火起こし器としての使用
# 虫眼鏡を使って太陽光を集中させ、火を起こす器具としての使用。アウトドア市場での需要を考えると、既存の火起こし器具と比較しても価値は見込める。
# {"value":3000}
#
# 3. ライターとしての使用
# 虫眼鏡を携帯用ライターとして使用するアイデア。実用性に乏しいため、ノベルティ商品としての価値はあるが、市場価値は限定的。
# {"value":1000}
#
# 4. 栞としての使用
# 虫眼鏡を栞として使用するアイデア。読書時に拡大鏡としても機能するため、一定の市場価値があると考えられる。
# {"value":1500}
#
# 5. 残す
# このアイデアは具体的な使用方法が示されていないため、評価はできません。
#
# 6. 万華鏡としての使用
# 虫眼鏡を利用して万華鏡を作るアイデア。既存の万華鏡と比較しても独自性があり、子供向けの商品として市場価値がある。
# {"value":2000}
#
# 7. インテリアとしての使用
# 虫眼鏡をインテリアとして使用するアイデア。デザイン次第で一定の市場価値があり、特に個性を求める消費者層に受ける可能性がある。
# {"value":4000}
#
# 8. カーテンとしての使用
# 虫眼鏡を連結させてカーテンとして使用するアイデア。実用性と安全性に疑問が残るため、市場価値は低いと考えられる。
# {"value":500}
#
# 9. 文鎮としての使用
# 虫眼鏡を文鎮として使用するアイデア。既存の文鎮と比較しても特に優れた機能はないが、デザイン性によっては一定の市場価値がある。
# {"value":1000}
#
# 10. 集光器としての使用
# 虫眼鏡を集光器として使用するアイデア。太陽光を利用した製品に応用可能であり、エコ製品としての市場価値がある。
# {"value":6000}
#
# 11. 望遠鏡としての使用
# 虫眼鏡を組み合わせて望遠鏡として使用するアイデア。既存の望遠鏡と比較して性能は劣るが、教育用やノベルティ商品としての価値はある。
# {"value":2500}
#
# 12. ハエたたきとしての使用
# 虫眼鏡をハエたたきとして使用するアイデア。既存のハエたたきと比較して特に優れた点はなく、市場価値は低い。
# {"value":500}
#
# 13. プリズムとしての使用
# 虫眼鏡をプリズムとして使用するアイデア。教育用具やデコレーションアイテムとして一定の市場価値がある。
# {"value":2000}
#
# 14. コンパスとしての使用
# 虫眼鏡をコンパスとして使用するアイデア。実用性に乏しく、市場価値は限定的。
# {"value":800}
#
# 15. 調理器具としての使用
# 虫眼鏡を利用して調理器具として使用するアイデア。太陽光を利用する点でエコ志向の市場に訴求可能だが、実用性には疑問が残る。
# {"value":3000}
#
# 16. 双眼鏡としての使用
# 虫眼鏡を組み合わせて双眼鏡として使用するアイデア。既存の双眼鏡と比較して性能は劣るが、低価格での提供が可能であれば市場価値はある。
# {"value":2500}
#
# 17. 器としての使用
# 虫眼鏡を食器として使用するアイデア。衛生面や実用性に疑問が残るため、市場価値は低い。
# {"value":500}
#
# 18. 火おこしとしての使用
# 虫眼鏡を使って火を起こすアイデア。2番目のアイデアと同様であり、アウトドア市場での需要を考えると、既存の火起こし器具と比較しても価値は見込める。
# {"value":3000}
#
# 19. テレビとしての使用
# 虫眼鏡を利用してテレビの画面を拡大するアイデア。既存の画面拡大ソリューションと比較して特に優れた点はなく、市場価値は限定的。
# {"value":1000}
#
# 20. 武器としての使用
# 虫眼鏡を武器として使用するアイデア。実用性や法的な問題から市場価値は極めて低い。
# {"value":100}'''
# Error: Unexpected number of lines for item 4.
# Retrying request 138 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 153 of 243
# Request 154 of 243
# Request 155 of 243
# Request 156 of 243
# Request 157 of 243
# Request 158 of 243
# Request 159 of 243
# Request 160 of 243
# Request 161 of 243
# Request 162 of 243
# Request 163 of 243
# Request 164 of 243
# Request 165 of 243
# Request 166 of 243
# Request 167 of 243
# Request 168 of 243
# Request 169 of 243
# Request 170 of 243
# Request 171 of 243
# Request 172 of 243
# Request 173 of 243
# Request 174 of 243
# Request 175 of 243
# Request 176 of 243
# Request 177 of 243
# Request 178 of 243
# Request 179 of 243
# Request 180 of 243
# Request 181 of 243
# Request 182 of 243
# Request 183 of 243
# Request 184 of 243
# Request 185 of 243
# Request 186 of 243
# Request 187 of 243
# Request 188 of 243
# Request 189 of 243
# Request 190 of 243
# Request 191 of 243
# Request 192 of 243
# Request 193 of 243
# Request 194 of 243
# Request 195 of 243
# Request 196 of 243
# Request 197 of 243
# Request 198 of 243
# Request 199 of 243
# Request 200 of 243
# Request 201 of 243
# Request 202 of 243
# Request 203 of 243
# Request 204 of 243
# Request 205 of 243
# Request 206 of 243
# Request 207 of 243
# Request 208 of 243
# Request 209 of 243
# Request 210 of 243
# Request 211 of 243
# Request 212 of 243
# Request 213 of 243
# Request 214 of 243
# Request 215 of 243
# Request 216 of 243
# Request 217 of 243
# Request 218 of 243
# Request 219 of 243
# Request 220 of 243
# Request 221 of 243
# Request 222 of 243
# Request 223 of 243
# Request 224 of 243
# Request 225 of 243
# Request 226 of 243
# Request 227 of 243
# Request 228 of 243
# Request 229 of 243
# Request 230 of 243
# Request 231 of 243
# Request 232 of 243
# Request 233 of 243
# Request 234 of 243
# Request 235 of 243
# Request 236 of 243
# Request 237 of 243
# Request 238 of 243
# Request 239 of 243
# Request 240 of 243
# Request 241 of 243
# Request 242 of 243
# Request 243 of 243

# %%
source.to_excel(f'gpt-ratings/{fname}-turbo.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}-turbo.xlsx')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.5731143039880092, pvalue=1.2988375214924529e-107),
#  'feasibility': SignificanceResult(statistic=0.5823239393553512, pvalue=7.501637865357762e-112),
#  'value': SignificanceResult(statistic=0.20546394191262024, pvalue=4.0887947239463433e-13)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (GPT{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='GPT')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

# plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (GPT)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='GPT')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# コルク
# 家の建築
# 20000000
# 20. コルクを家の建築材料として使用
# エコフレンドリーな建築材料としてのコルクは、特にサステナブルな建築を求める市場で高い価値を持つ可能性があり、価格は数百万円から数千万円程度。
#
# レンガ
# 教室
# 10000000
# 18. レンガを教室として使用
# レンガを教室の建築材料として使用するアイデアは、建築市場において一定の価値がある。
#
# ストロー
# 食料
# 500000
# 1. ストローを食料として使用するアイデア
# 食料としてのストローは非常に珍しいが、食品業界では新しい食材や食品の開発に多額の投資がされている。
#
# レンガ
# 家
# 10000000
# 8. レンガで家を建てる
# レンガを使用して家を建てるアイデアは、レンガ造りの家の市場価値と比較される。
#
# レンガ
# 階段
# 500000
# 17. レンガを階段として使用
# レンガを階段として使用するアイデアは、レンガ造りの階段の市場価値と比較される。
#
# レンガ
# トイレ
# 500000
# 19. トイレ
# レンガを使ってトイレを建てるアイデア。耐久性とプライバシーが保たれるため、市場価値がある。
#
# コルク
# 住居
# 10000000
# 20. コルクを使った住居
# コルクを住居として使用するアイデアは、その断熱性や耐久性を活かしたエコフレンドリーな建築材料としての可能性があります。住居の価格は非常に幅広いですが、コルクを主材料とした住居は数百万円から数千万円で販売される可能性があります。

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (GPT)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.21$, $p = 4e-12$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 3. Using the pen as a refrigerator.
# This idea is highly novel due to the significant difference between the typical function of a pen and the complex functionality of a refrigerator.
# {"novelty": 95}

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['feasibility_raw'].item())
# Out:
# 3. 冷蔵庫
# ボールペンを冷蔵庫として使用するアイデア。技術的に非現実的であり、ボールペンのサイズや機能からも全く実現不可能。
# {"feasibility": 1}

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['value_raw'].item())
# Out:
# 3. ボールペンを使った冷蔵庫
# このアイデアは実現不可能に近いため、既存の冷蔵庫の価格とは比較できないが、一般的な冷蔵庫は数万円から数十万円。
# {"value":0}
