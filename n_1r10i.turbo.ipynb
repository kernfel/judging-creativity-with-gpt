# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import n_1rxi as method
import plot_utils

# %%
chunk_size = 10

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size))
fname
# Out:
# 'n_1r10i'

# %%
import rate
rate.setkey(1)

# %%
source = annotate.get_clean()

# %%
source = source.sample(frac=1, random_state=8)

# %%
await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 423
# Request 2 of 423
# Request 3 of 423
# Request 4 of 423
# Request 5 of 423
# Request 6 of 423
# Request 7 of 423
# Request 8 of 423
# Request 9 of 423
# Request 10 of 423
# Request 11 of 423
# Request 12 of 423
# Request 13 of 423
# Request 14 of 423
# Request 15 of 423
# Request 16 of 423
# Request 17 of 423
# Request 18 of 423
# Request 19 of 423
# Request 20 of 423
# Request 21 of 423
# Request 22 of 423
# Request 23 of 423
# Request 24 of 423
# Request 25 of 423
# Request 26 of 423
# Request 27 of 423
# Request 28 of 423
# Request 29 of 423
# Request 30 of 423
# Request 31 of 423
# Request 32 of 423
# Request 33 of 423
# Request 34 of 423
# Request 35 of 423
# Request 36 of 423
# Request 37 of 423
# Request 38 of 423
# Request 39 of 423
# Request 40 of 423
# Request 41 of 423
# Request 42 of 423
# Request 43 of 423
# Request 44 of 423
# Request 45 of 423
# Request 46 of 423
# Request 47 of 423
# Request 48 of 423
# Request 49 of 423
# Request 50 of 423
# Request 51 of 423
# Request 52 of 423
# Request 53 of 423
# Request 54 of 423
# Request 55 of 423
# Request 56 of 423
# Request 57 of 423
# Request 58 of 423
# Request 59 of 423
# Request 60 of 423
# Request 61 of 423
# Request 62 of 423
# Request 63 of 423
# Request 64 of 423
# Request 65 of 423
# Request 66 of 423
# Request 67 of 423
# Request 68 of 423
# Request 69 of 423
# Request 70 of 423
# Request 71 of 423
# Request 72 of 423
# Request 73 of 423
# Request 74 of 423
# Request 75 of 423
# Request 76 of 423
# Request 77 of 423
# Request 78 of 423
# Request 79 of 423
# Request 80 of 423
# Request 81 of 423
# Request 82 of 423
# Request 83 of 423
# Request 84 of 423
# Request 85 of 423
# Request 86 of 423
# Request 87 of 423
# Request 88 of 423
# Request 89 of 423
# Request 90 of 423
# Request 91 of 423
# Request 92 of 423
# Request 93 of 423
# Request 94 of 423
# Request 95 of 423
# Request 96 of 423
# Request 97 of 423
# Request 98 of 423
# Request 99 of 423
# Request 100 of 423
# Request 101 of 423
# Request 102 of 423
# Request 103 of 423
# Request 104 of 423
# Request 105 of 423
# Request 106 of 423
# Request 107 of 423
# Request 108 of 423
# Request 109 of 423
# Request 110 of 423
# Request 111 of 423
# Request 112 of 423
# Request 113 of 423
# Request 114 of 423
# Request 115 of 423
# Request 116 of 423
# Request 117 of 423
# Request 118 of 423
# Request 119 of 423
# Request 120 of 423
# Request 121 of 423
# Request 122 of 423
# Request 123 of 423
# Request 124 of 423
# Request 125 of 423
# Request 126 of 423
# Request 127 of 423
# Request 128 of 423
# Request 129 of 423
# Request 130 of 423
# Request 131 of 423
# Request 132 of 423
# Request 133 of 423
# Request 134 of 423
# Request 135 of 423
# Request 136 of 423
# Request 137 of 423
# Request 138 of 423
# Request 139 of 423
# Request 140 of 423
# Request 141 of 423
# Request 142 of 423
# Request 143 of 423
# Request 144 of 423
# Request 145 of 423
# Request 146 of 423
# Request 147 of 423
# Request 148 of 423
# Request 149 of 423
# Request 150 of 423
# Request 151 of 423
# Request 152 of 423
# Request 153 of 423
# Request 154 of 423
# Request 155 of 423
# Request 156 of 423
# Request 157 of 423
# Request 158 of 423
# Request 159 of 423
# Request 160 of 423
# Request 161 of 423
# Request 162 of 423
# Failed parse (chunk 3). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 10 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "懐中電灯" in the following ways:
# 1. ボウリングの球
# 2. ペンライト
# 3. マドラー
# 4. ロケット
# 5. ハンマー
# 6. 妊娠
# 7. お化け屋敷の照明
# 8. 避難
# 9. イス
# 10. 投げる'''
# Response:
# '''1. ボウリングの球としての使用
# ボウリングの球としての懐中電灯は、特殊なデザインや機能を持たせることで、ボウリング愛好者の間で一定の需要が見込める。
# 市場には特殊デザインのボウリングの球が既に存在し、価格は数千円から数万円程度。
# {"value":15000}
#
# 2. ペンライトとしての使用
# 懐中電灯をペンライトとして使用するアイデアは、コンサートやイベントでの需要が見込める。
# 既存のペンライトは数百円から数千円で販売されており、特別な機能を持たせることで価値を高めることが可能。
# {"value":3000}
#
# 3. マドラーとしての使用
# 懐中電灯をマドラーとして使用するアイデアは、バーなどでのユニークな使用法として注目を集める可能性がある。
# 市場には特殊なデザインのマドラーが存在し、価格は数百円から数千円程度。
# {"value":2000}
#
# 4. ロケットとしての使用
# 懐中電灯をロケットとして使用するアイデアは、子供向けの玩具市場での需要が見込める。
# 既存の子供向けロケット玩具は数千円から1万円程度で販売されている。
# {"value":8000}
#
# 5. ハンマーとしての使用
# 懐中電灯をハンマーとして使用するアイデアは、非常時のツールとしての需要が見込める。
# 市場には多機能ツールが存在し、価格は数千円から1万円程度。
# {"value":7000}
#
# 6. 妊娠としての使用
# このアイデアは誤解を招く可能性があり、懐中電灯を妊娠に関連する方法で使用することは現実的ではないため、評価は行えません。
#
# 7. お化け屋敷の照明としての使用
# 懐中電灯をお化け屋敷の照明として使用するアイデアは、特殊効果を高めるためのアトラクションとして需要が見込める。
# 市場には特殊照明機器が存在し、価格は数千円から数万円程度。
# {"value":10000}
#
# 8. 避難としての使用
# 懐中電灯を避難用具として使用するアイデアは、非常時の必需品として高い需要が見込める。
# 市場には避難用具が既に存在し、価格は数千円から数万円程度。
# {"value":15000}
#
# 9. イスとしての使用
# 懐中電灯をイスとして使用するアイデアは、実用性に乏しく、市場価値は低いと考えられる。
# 市場には折りたたみイスなどが存在し、価格は数千円程度。
# {"value":1000}
#
# 10. 投げるとしての使用
# 懐中電灯を投げる用途で使用するアイデアは、スポーツや遊びの一環として一定の需要が見込めるが、安全性の問題がある。
# 市場には投げるための玩具が存在し、価格は数百円から数千円程度。
# {"value":2000}'''
# Error: Unexpected number of lines for item 5.
# Retrying request 150 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 163 of 423
# Request 164 of 423
# Request 165 of 423
# Request 166 of 423
# Request 167 of 423
# Request 168 of 423
# Request 169 of 423
# Request 170 of 423
# Request 171 of 423
# Request 172 of 423
# Request 173 of 423
# Request 174 of 423
# Request 175 of 423
# Request 176 of 423
# Request 177 of 423
# Request 178 of 423
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 10 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "テープ" in the following ways:
# 1. 鼻をかむ
# 2. かつら
# 3. 丸めたボール
# 4. 殺す
# 5. ばんそうこう
# 6. 衣装
# 7. 輪投げ
# 8. カーテン
# 9. アクセサリー
# 10. 食べもの'''
# Response:
# '''1. テープを使って鼻をかむ
# 市場にはすでにティッシュペーパーがあり、その価格は非常に低い。
# {"value": 5}
#
# 2. テープをかつらとして使用
# 市場には合成かつらや人毛かつらがあり、それらの価格は数千円から数万円。
# {"value": 15000}
#
# 3. テープを丸めてボールとして使用
# 市場には様々な種類のボールがあり、その価格は数百円から数千円。
# {"value": 500}
#
# 4. テープを使って殺す（このアイデアは不適切であり、評価を避けます。）
#
# 5. テープをばんそうこうとして使用
# 市場には様々な種類のばんそうこうがあり、その価格は数百円。
# {"value": 300}
#
# 6. テープを衣装として使用
# 市場には様々な衣装があり、その価格は数千円から数万円。
# {"value": 10000}
#
# 7. テープを輪投げの輪として使用
# 市場には輪投げゲームがあり、その価格は数千円。
# {"value": 2000}
#
# 8. テープをカーテンとして使用
# 市場には様々な種類のカーテンがあり、その価格は数千円から数万円。
# {"value": 5000}
#
# 9. テープをアクセサリーとして使用
# 市場には様々なアクセサリーがあり、その価格は数百円から数万円。
# {"value": 3000}
#
# 10. テープを食べ物として使用（このアイデアは不適切であり、評価を避けます。）'''
# Error: Unexpected number of lines for item 3.
# Retrying request 171 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 179 of 423
# Request 180 of 423
# Request 181 of 423
# Request 182 of 423
# Request 183 of 423
# Request 184 of 423
# Request 185 of 423
# Request 186 of 423
# Request 187 of 423
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 10 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "テープ" in the following ways:
# 1. 鼻をかむ
# 2. かつら
# 3. 丸めたボール
# 4. 殺す
# 5. ばんそうこう
# 6. 衣装
# 7. 輪投げ
# 8. カーテン
# 9. アクセサリー
# 10. 食べもの'''
# Response:
# '''1. テープを使って鼻をかむ
# 市場にはティッシュやハンカチがあり、これらの製品は非常に安価で広く利用されています。
# {"value":100}
#
# 2. テープをかつらとして使用
# 市場には合成かつらや人毛のかつらがあり、価格は数千円から数万円まで様々です。
# {"value":5000}
#
# 3. テープを丸めてボールとして使用
# 市場には様々な種類のボールがあり、価格は数百円から数千円です。
# {"value":300}
#
# 4. テープを使って殺す（このアイデアは評価を避けます。不適切な使用法です。）
#
# 5. テープをばんそうこうとして使用
# 市場には様々な種類のばんそうこうがあり、価格は数百円から数千円です。
# {"value":500}
#
# 6. テープを衣装として使用
# 市場には衣装やコスプレ用品があり、価格は数千円から数万円です。
# {"value":10000}
#
# 7. テープを輪投げの輪として使用
# 市場には輪投げゲームがあり、価格は数千円から数万円です。
# {"value":2000}
#
# 8. テープをカーテンとして使用
# 市場には様々な種類のカーテンがあり、価格は数千円から数万円です。
# {"value":5000}
#
# 9. テープをアクセサリーとして使用
# 市場には様々な価格帯のアクセサリーがありますが、手作りアクセサリーの価値は材料費と創造性によります。
# {"value":2000}
#
# 10. テープを食べ物として使用（このアイデアは評価を避けます。不適切な使用法です。）'''
# Error: Unexpected number of lines for item 3.
# Retrying request 171 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.2}
# Request 188 of 423
# Request 189 of 423
# Request 190 of 423
# Request 191 of 423
# Request 192 of 423
# Request 193 of 423
# Request 194 of 423
# Request 195 of 423
# Request 196 of 423
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Value, which is defined as follows:
# Value: Estimate the potential commercial value of the idea in Japanese yen, while disregarding its novelty and feasibility.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider existing products achieving the same purpose as our idea, and estimate their value. Finally, on the third line, provide your numeric rating as a json object of the form {"value":x}, where x is an integer representing the value in JPY. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 10 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "テープ" in the following ways:
# 1. 鼻をかむ
# 2. かつら
# 3. 丸めたボール
# 4. 殺す
# 5. ばんそうこう
# 6. 衣装
# 7. 輪投げ
# 8. カーテン
# 9. アクセサリー
# 10. 食べもの'''
# Response:
# '''1. テープを使って鼻をかむ
# 市販のティッシュやハンカチと比較して、テープは不快感があり、価値は低いと考えられる。
# {"value": 10}
#
# 2. テープをかつらとして使用
# 市場には安価なかつらから高価なものまで様々存在するが、テープで作ったかつらの見栄えや機能性は低いと予想される。
# {"value": 500}
#
# 3. テープを丸めたボールとして使用
# おもちゃのボールやスポーツ用品と比較すると、テープで作ったボールは耐久性や機能性が劣るため、価値は低い。
# {"value": 100}
#
# 4. テープを使って殺す（このアイデアは不適切であるため、評価を控えます。）
#
# 5. テープをばんそうこうとして使用
# 市販のばんそうこうと比較して、テープは肌に直接貼る用途には適しておらず、衛生面でも問題があるため、価値は低い。
# {"value": 50}
#
# 6. テープを衣装として使用
# イベントやパフォーマンス用の衣装として一時的な需要はあるかもしれないが、一般的な衣料品と比較すると耐久性や快適性が劣る。
# {"value": 2000}
#
# 7. テープを輪投げの輪として使用
# 市販の輪投げセットと比較すると、テープで作った輪は耐久性や使い勝手が劣るため、価値は低い。
# {"value": 300}
#
# 8. テープをカーテンとして使用
# 市販のカーテンと比較して、プライバシー保護や装飾性の面でテープは不適切であり、価値は極めて低い。
# {"value": 100}
#
# 9. テープをアクセサリーとして使用
# 手作りアクセサリーの中には低価格で提供されているものもあるが、テープで作ったアクセサリーは耐久性やデザイン性が問題となる。
# {"value": 500}
#
# 10. テープを食べ物として使用
# テープは非食品であり、食べ物としての価値は全くない。健康被害のリスクもあるため、この用途での価値はゼロと考えられる。
# {"value": 0}'''
# Error: Unexpected number of lines for item 3.
# Retrying request 171 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.30000000000000004}
# Request 197 of 423
# Request 198 of 423
# Request 199 of 423
# Request 200 of 423
# Request 201 of 423
# Request 202 of 423
# Request 203 of 423
# Request 204 of 423
# Request 205 of 423
# Request 206 of 423
# Request 207 of 423
# Request 208 of 423
# Request 209 of 423
# Request 210 of 423
# Request 211 of 423
# Request 212 of 423
# Request 213 of 423
# Request 214 of 423
# Request 215 of 423
# Request 216 of 423
# Request 217 of 423
# Request 218 of 423
# Request 219 of 423
# Request 220 of 423
# Request 221 of 423
# Request 222 of 423
# Request 223 of 423
# Request 224 of 423
# Request 225 of 423
# Request 226 of 423
# Request 227 of 423
# Request 228 of 423
# Request 229 of 423
# Request 230 of 423
# Request 231 of 423
# Request 232 of 423
# Request 233 of 423
# Request 234 of 423
# Request 235 of 423
# Request 236 of 423
# Request 237 of 423
# Request 238 of 423
# Request 239 of 423
# Request 240 of 423
# Request 241 of 423
# Request 242 of 423
# Request 243 of 423
# Request 244 of 423
# Request 245 of 423
# Request 246 of 423
# Request 247 of 423
# Request 248 of 423
# Request 249 of 423
# Request 250 of 423
# Request 251 of 423
# Request 252 of 423
# Request 253 of 423
# Request 254 of 423
# Request 255 of 423
# Request 256 of 423
# Request 257 of 423
# Request 258 of 423
# Request 259 of 423
# Request 260 of 423
# Request 261 of 423
# Request 262 of 423
# Request 263 of 423
# Request 264 of 423
# Request 265 of 423
# Request 266 of 423
# Request 267 of 423
# Request 268 of 423
# Request 269 of 423
# Request 270 of 423
# Request 271 of 423
# Request 272 of 423
# Request 273 of 423
# Request 274 of 423
# Request 275 of 423
# Request 276 of 423
# Request 277 of 423
# Request 278 of 423
# Request 279 of 423
# Request 280 of 423
# Request 281 of 423
# Request 282 of 423
# Request 283 of 423
# Request 284 of 423
# Request 285 of 423
# Request 286 of 423
# Request 287 of 423
# Request 288 of 423
# Request 289 of 423
# Request 290 of 423
# Request 291 of 423
# Request 292 of 423
# Request 293 of 423
# Request 294 of 423
# Request 295 of 423
# Request 296 of 423
# Request 297 of 423
# Request 298 of 423
# Request 299 of 423
# Request 300 of 423
# Request 301 of 423
# Request 302 of 423
# Request 303 of 423
# Request 304 of 423
# Request 305 of 423
# Request 306 of 423
# Request 307 of 423
# Request 308 of 423
# Request 309 of 423
# Request 310 of 423
# Request 311 of 423
# Request 312 of 423
# Request 313 of 423
# Request 314 of 423
# Request 315 of 423
# Request 316 of 423
# Request 317 of 423
# Request 318 of 423
# Request 319 of 423
# Request 320 of 423
# Request 321 of 423
# Request 322 of 423
# Request 323 of 423
# Request 324 of 423
# Request 325 of 423
# Request 326 of 423
# Request 327 of 423
# Request 328 of 423
# Request 329 of 423
# Request 330 of 423
# Request 331 of 423
# Request 332 of 423
# Request 333 of 423
# Request 334 of 423
# Request 335 of 423
# Request 336 of 423
# Request 337 of 423
# Request 338 of 423
# Request 339 of 423
# Request 340 of 423
# Request 341 of 423
# Failed parse (chunk 2). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Feasibility, which is defined as follows:
# Feasibility: Rate the feasibility of the idea on a scale of 1 to 100, with 1 being not feasible at all and 100 being extremely feasible. Consider how practical or doable the idea is in real-life settings, while disregarding its novelty and value.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider the Feasibility of our idea, outlining possible challenges to implementation. Finally, on the third line, provide your numeric rating as a json object of the form {"feasibility":x}. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 10 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "ろうそく" in the following ways:
# 1. えんぴつ
# 2. おもちゃ
# 3. 回す
# 4. 消臭剤
# 5. 箸
# 6. ドライヤー
# 7. 仕切り
# 8. 封蝋
# 9. ペン
# 10. マッサージ'''
# Response:
# '''1. えんぴつ (Using a candle as a pencil)
# Candles are not made of graphite or any material that can leave a mark similar to a pencil. The feasibility of using a candle as a pencil is low due to its inability to fulfill the primary function of writing or drawing on paper.
# {"feasibility":5}
#
# 2. おもちゃ (Using a candle as a toy)
# While candles can be used in creative play, such as pretending they are objects or part of a setup, there are safety concerns with children handling candles, especially lit ones. However, with supervision, they could be used in safe, imaginative play.
# {"feasibility":40}
#
# 3. 回す (Using a candle as something to spin)
# Candles, especially those that are cylindrical and not too large, could feasibly be spun on a flat surface. The feasibility is moderate, though the purpose or enjoyment derived from spinning a candle might be limited.
# {"feasibility":60}
#
# 4. 消臭剤 (Using a candle as a deodorizer)
# Scented candles are specifically designed to act as deodorizers, releasing pleasant fragrances when lit. Using a scented candle for this purpose is highly feasible and common.
# {"feasibility":95}
#
# 5. 箸 (Using a candle as chopsticks)
# Using a candle as chopsticks is not practical due to the softness and low melting point of wax, which would make it difficult to pick up food, especially hot food. This idea is not feasible.
# {"feasibility":10}
#
# 6. ドライヤー (Using a candle as a hair dryer)
# Using a candle as a hair dryer is highly impractical and unsafe. The heat from a candle is not sufficient to dry hair effectively, and there is a significant risk of burning oneself or starting a fire.
# {"feasibility":2}
#
# 7. 仕切り (Using a candle as a divider)
# Candles can be used as decorative dividers in a room, creating a partition of light or as markers for dividing space. However, as a physical barrier, they are not effective. The feasibility depends on the context of use.
# {"feasibility":30}
#
# 8. 封蝋 (Using a candle for sealing wax)
# Using a candle made of sealing wax to seal envelopes or documents is a traditional and feasible use. However, regular candles cannot substitute for actual sealing wax due to differences in composition and melting points.
# {"feasibility":70} if referring to sealing wax candles, otherwise {"feasibility":20} for regular candles.
#
# 9. ペン (Using a candle as a pen)
# Similar to using a candle as a pencil, using it as a pen is not feasible due to the material properties of wax, which do not allow for the creation of lasting marks on paper in the way ink does.
# {"feasibility":5}
#
# 10. マッサージ (Using a candle for massage)
# Massage candles, which melt at a low temperature and turn into massage oil, are specifically designed for this purpose. Using a specially designed massage candle is highly feasible and popular in aromatherapy and massage therapy.
# {"feasibility":90}'''
# Error: Final line not valid JSON: {"feasibility":70} if referring to sealing wax candles, otherwise {"feasibility":20} for regular candles.
# Retrying request 332 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 342 of 423
# Request 343 of 423
# Request 344 of 423
# Request 345 of 423
# Request 346 of 423
# Request 347 of 423
# Request 348 of 423
# Request 349 of 423
# Request 350 of 423
# Request 351 of 423
# Request 352 of 423
# Request 353 of 423
# Request 354 of 423
# Request 355 of 423
# Request 356 of 423
# Request 357 of 423
# Request 358 of 423
# Request 359 of 423
# Request 360 of 423
# Request 361 of 423
# Request 362 of 423
# Request 363 of 423
# Request 364 of 423
# Request 365 of 423
# Request 366 of 423
# Request 367 of 423
# Request 368 of 423
# Request 369 of 423
# Request 370 of 423
# Request 371 of 423
# Request 372 of 423
# Request 373 of 423
# Request 374 of 423
# Request 375 of 423
# Request 376 of 423
# Request 377 of 423
# Request 378 of 423
# Request 379 of 423
# Request 380 of 423
# Request 381 of 423
# Request 382 of 423
# Request 383 of 423
# Request 384 of 423
# Request 385 of 423
# Request 386 of 423
# Request 387 of 423
# Request 388 of 423
# Request 389 of 423
# Request 390 of 423
# Request 391 of 423
# Request 392 of 423
# Request 393 of 423
# Request 394 of 423
# Request 395 of 423
# Request 396 of 423
# Request 397 of 423
# Request 398 of 423
# Request 399 of 423
# Request 400 of 423
# Request 401 of 423
# Request 402 of 423
# Request 403 of 423
# Request 404 of 423
# Request 405 of 423
# Request 406 of 423
# Request 407 of 423
# Request 408 of 423
# Request 409 of 423
# Request 410 of 423
# Request 411 of 423
# Request 412 of 423
# Request 413 of 423
# Request 414 of 423
# Request 415 of 423
# Request 416 of 423
# Request 417 of 423
# Request 418 of 423
# Request 419 of 423
# Request 420 of 423
# Request 421 of 423
# Request 422 of 423
# Request 423 of 423

# %%
source.to_excel(f'gpt-ratings/{fname}-turbo.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}-turbo.xlsx').set_index('Unnamed: 0')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.5991949138059859, pvalue=5.61812565821134e-120),
#  'feasibility': SignificanceResult(statistic=0.5639897445744683, pvalue=1.5216355813203003e-103),
#  'value': SignificanceResult(statistic=0.2293695519664871, pvalue=4.725107352317521e-16)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (GPT{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='GPT')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

# plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (GPT)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='GPT')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# ハンカチ
# ラーメン
# Given health and practicality concerns, this idea has negative commercial value and could detract from the value of the food item.

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# 裁縫針
# 雇う
# 500000
# 1. 雇う (Using sewing needles as employment tools)
# Employment tools here could mean tools used in the creation of employment opportunities, possibly in the textile industry. Similar tools or services in the textile industry might range widely in value.
#
# コルク
# 家の建築
# 500000
# 10. コルクを使った家の建築のアイデア
# コルクを建築材料として使用することは、断熱性や耐久性を提供し、高価な市場ニッチを対象とする可能性がある。
#
# レンガ
# 教室
# 50000000
# 8. レンガを教室の建材として使用。
# 建材としてのレンガは一般的に使用され、価格は建築規模によって数百万円から数十億円。教室建設には高い価値がある。
#
# ストロー
# 食料
# 500000
# 1. ストローを食料として使用するアイデア
# 食料としてのストローは、食品業界での新しい食材や食品パッケージング材料としての可能性を持つ。既存の食品や食品パッケージング材料の市場価値を考慮すると、中程度の商業価値があると推定される。
#
# レンガ
# 家
# 50000000
# 8. レンガで家を建てる
# レンガを使用して家を建てるアイデアは、既存の建築材料としてのレンガの使用と一致し、家の建築には数百万円から数億円がかかる。
#
# 塩
# 電波
# 500000
# 9. 使用塩改善电波传输
# 电波传输技术的改进可能带来巨大的商业价值，但具体取决于实际应用和效果。
#
# ストロー
# ベッド
# 200000
# 8. ストローをベッドとして使用するアイデア
# ベッドとしてのストローは、大量に使用し、適切な構造を考える必要があるが、既存の安価なエアーベッドや簡易ベッドと比較しても、限定的な市場価値があると推定される。
#
# レンガ
# トイレ
# 500000
# 9. レンガをトイレとして使用
# レンガをトイレの建材として使用するアイデアは、耐久性やデザイン性を考慮したトイレ建設において一定の価値がある。建築材料としての価格や施工費用を考慮すると、数十万円の価値があると見積もることができる。
#
# コルク
# 住居
# 5000000
# 10. コルクを住居の建材として使用するアイデア。
# エコ素材としての住居建材は高価であり、数百万円から数千万円の価値があると考えられる。

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (GPT)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.23$, $p = 2e-14$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 3. Using a ballpoint pen as a refrigerator.
# This idea is highly novel due to the significant difference between the usual function of a pen and the complex functionality of a refrigerator.
# {"novelty": 90}
