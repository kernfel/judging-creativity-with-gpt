# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import n_1rxi as method
import plot_utils

# %%
chunk_size = 50

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size))
fname
# Out:
# 'n_1r50i'

# %%
import rate
rate.setkey(1)

# %%
source = annotate.get_clean()

# %%
source = source.sample(frac=1, random_state=8)

# %%
await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 90
# Request 2 of 90
# Request 3 of 90
# Request 4 of 90
# Request 5 of 90
# Request 6 of 90
# Request 7 of 90
# Request 8 of 90
# Request 9 of 90
# Request 10 of 90
# Request 11 of 90
# Request 12 of 90
# Request 13 of 90
# Request 14 of 90
# Request 15 of 90
# Request 16 of 90
# Request 17 of 90
# Request 18 of 90
# Request 19 of 90
# Request 20 of 90
# Request 21 of 90
# Request 22 of 90
# Request 23 of 90
# Request 24 of 90
# Request 25 of 90
# Request 26 of 90
# Request 27 of 90
# Request 28 of 90
# Request 29 of 90
# Request 30 of 90
# Request 31 of 90
# Request 32 of 90
# Request 33 of 90
# Request 34 of 90
# Request 35 of 90
# Request 36 of 90
# Request 37 of 90
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Novelty, which is defined as follows:
# Novelty: Rate the novelty of the idea on a scale of 1 to 100, with 1 being not novel at all and 100 being extremely novel. Consider how unique, original, or surprising the idea is, while disregarding its feasibility and value.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider other unconventional uses of the item, including those listed, and compare the idea to these in terms of its Novelty. Finally, on the third line, provide your numeric rating as a json object of the form {"novelty":x}. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 45 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "金属の鍵" in the following ways:
# 1. 造金
# 2. お守り
# 3. 耳かき
# 4. スクレーパー
# 5. ピン
# 6. ドリル
# 7. 掃除用ブラシ
# 8. 溶かす
# 9. くらわす
# 10. 戦う
# 11. ネックレス
# 12. ガムとりのへら
# 13. ピアス
# 14. 風鈴
# 15. 料亭の箸
# 16. 髪飾り
# 17. 穴をあける
# 18. 釘
# 19. ボール
# 20. 箸
# 21. 研磨
# 22. 積み木
# 23. ハンマー
# 24. アクセサリー
# 25. 枕
# 26. ファッションアイテム
# 27. 導線
# 28. 段ボールをあけるナイフ
# 29. 栓抜き
# 30. まげる
# 31. おもり
# 32. カッター
# 33. スクラッチを削るもの
# 34. 剣（おもちゃ）
# 35. 折る
# 36. 燃やす
# 37. 電線
# 38. ナイフ
# 39. コーラ
# 40. ハサミ
# 41. フォーチュンクッキーの中身
# 42. 彫刻刀
# 43. スコップ
# 44. ドア
# 45. スクラッチ'''
# Response:
# '''1. 金属の鍵を造金に使用するアイデア
# 造金は、金属を金や他の貴金属に変える古代の錬金術の概念であり、鍵をその材料として使用するのは創造的であるが、非常に非現実的なアイデアです。
# {"novelty":75}
#
# 2. 金属の鍵をお守りとして使用するアイデア
# 鍵をお守りとして使用するのは、その形状や素材が持つ象徴的な意味に基づいており、比較的一般的な考え方ですが、それでもややユニークな使い方です。
# {"novelty":40}
#
# 3. 金属の鍵を耳かきとして使用するアイデア
# 鍵を耳かきとして使用するのは衛生的ではないという点を除けば、非常にユニークで意外性のあるアイデアです。
# {"novelty":70}
#
# 4. 金属の鍵をスクレーパーとして使用するアイデア
# 鍵をスクレーパーとして使用するのは、その形状がスクレーパーとして機能するため、比較的一般的な考え方です。
# {"novelty":30}
#
# 5. 金属の鍵をピンとして使用するアイデア
# 鍵をピンとして使用するのは、その形状や強度がピンの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 6. 金属の鍵をドリルとして使用するアイデア
# 鍵をドリルとして使用するのは、その形状や強度がドリルのように機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":80}
#
# 7. 金属の鍵を掃除用ブラシとして使用するアイデア
# 鍵を掃除用ブラシとして使用するのは、その形状がブラシとして機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":75}
#
# 8. 金属の鍵を溶かすアイデア
# 鍵を溶かして他の用途に利用するのは、リサイクルや再利用の観点から見ると創造的ですが、特に珍しいアイデアではありません。
# {"novelty":45}
#
# 9. 金属の鍵をくらわすアイデア
# 「くらわす」という用途が不明瞭であり、一般的な用途と比較してもその意図や方法が理解しにくいため、非常にユニークなアイデアと言えます。
# {"novelty":90}
#
# 10. 金属の鍵で戦うアイデア
# 鍵を武器として使用するのは、非常に非現実的であり、通常の鍵の用途から大きく逸脱しているため、非常にユニークなアイデアです。
# {"novelty":85}
#
# 11. 金属の鍵をネックレスとして使用するアイデア
# 鍵をネックレスとして使用するのは、ファッションアクセサリーとしての鍵の利用は比較的一般的なアイデアです。
# {"novelty":35}
#
# 12. 金属の鍵をガムとりのへらとして使用するアイデア
# 鍵をガムを取り除くためのへらとして使用するのは、その形状が役立つという点で創造的ですが、非常に特異なアイデアではありません。
# {"novelty":60}
#
# 13. 金属の鍵をピアスとして使用するアイデア
# 鍵をピアスとして使用するのは、ファッションアクセサリーとしての利用は一般的ですが、ピアスとしての使用はややユニークです。
# {"novelty":55}
#
# 14. 金属の鍵を風鈴として使用するアイデア
# 鍵を風鈴として使用するのは、その音色を楽しむという点で創造的であり、比較的ユニークなアイデアです。
# {"novelty":65}
#
# 15. 金属の鍵を料亭の箸として使用するアイデア
# 鍵を料亭の箸として使用するのは、非常にユニークで意外性のあるアイデアですが、実用性に欠ける可能性があります。
# {"novelty":85}
#
# 16. 金属の鍵を髪飾りとして使用するアイデア
# 鍵を髪飾りとして使用するのは、ファッションアクセサリーとしての利用は一般的ですが、髪飾りとしての使用はややユニークです。
# {"novelty":55}
#
# 17. 金属の鍵で穴をあけるアイデア
# 鍵で穴をあけるのは、その形状や強度が穴をあける道具として機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":70}
#
# 18. 金属の鍵を釘として使用するアイデア
# 鍵を釘として使用するのは、その形状や強度が釘の代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 19. 金属の鍵をボールとして使用するアイデア
# 鍵をボールとして使用するのは、その形状や重さがボールとしての機能を果たすことは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":80}
#
# 20. 金属の鍵を箸として使用するアイデア
# 鍵を箸として使用するのは、その形状が箸として機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":75}
#
# 21. 金属の鍵を研磨として使用するアイデア
# 鍵を研磨材として使用するのは、その素材が研磨に利用できるという点で創造的ですが、特に珍しいアイデアではありません。
# {"novelty":45}
#
# 22. 金属の鍵を積み木として使用するアイデア
# 鍵を積み木として使用するのは、その形状やサイズが積み木のように機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":80}
#
# 23. 金属の鍵をハンマーとして使用するアイデア
# 鍵をハンマーとして使用するのは、その形状や強度がハンマーのように機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":70}
#
# 24. 金属の鍵をアクセサリーとして使用するアイデア
# 鍵をアクセサリーとして使用するのは、ファッションアクセサリーとしての利用は比較的一般的なアイデアです。
# {"novelty":35}
#
# 25. 金属の鍵を枕として使用するアイデア
# 鍵を枕として使用するのは、その形状や硬さが枕としての機能を果たすことは非常に難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":90}
#
# 26. 金属の鍵をファッションアイテムとして使用するアイデア
# 鍵をファッションアイテムとして使用するのは、ファッションアクセサリーとしての利用は比較的一般的なアイデアです。
# {"novelty":35}
#
# 27. 金属の鍵を導線として使用するアイデア
# 鍵を導線として使用するのは、その素材が電気を導く性質を持つという点で創造的ですが、特に珍しいアイデアではありません。
# {"novelty":45}
#
# 28. 金属の鍵を段ボールをあけるナイフとして使用するアイデア
# 鍵を段ボールを開けるナイフとして使用するのは、その形状がナイフの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 29. 金属の鍵を栓抜きとして使用するアイデア
# 鍵を栓抜きとして使用するのは、その形状が栓抜きの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 30. 金属の鍵をまげるアイデア
# 鍵を曲げること自体が目的のアイデアは、特に目新しい用途を提案しているわけではないため、ユニークさは低いです。
# {"novelty":20}
#
# 31. 金属の鍵をおもりとして使用するアイデア
# 鍵をおもりとして使用するのは、その重さを利用するという点で創造的ですが、特に珍しいアイデアではありません。
# {"novelty":45}
#
# 32. 金属の鍵をカッターとして使用するアイデア
# 鍵をカッターとして使用するのは、その形状がカッターの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 33. 金属の鍵をスクラッチを削るものとして使用するアイデア
# 鍵をスクラッチカードを削る道具として使用するのは、その形状が役立つという点で創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 34. 金属の鍵を剣（おもちゃ）として使用するアイデア
# 鍵をおもちゃの剣として使用するのは、非常に非現実的であり、通常の鍵の用途から大きく逸脱しているため、非常にユニークなアイデアです。
# {"novelty":85}
#
# 35. 金属の鍵を折るアイデア
# 鍵を折ること自体が目的のアイデアは、特に目新しい用途を提案しているわけではないため、ユニークさは低いです。
# {"novelty":20}
#
# 36. 金属の鍵を燃やすアイデア
# 鍵を燃やすというのは、金属の性質を考えると非常に非現実的であり、意外性はあるものの、実用的な用途とは言い難いです。
# {"novelty":30}
#
# 37. 金属の鍵を電線として使用するアイデア
# 鍵を電線として使用するのは、その素材が電気を導く性質を持つという点で創造的ですが、特に珍しいアイデアではありません。
# {"novelty":45}
#
# 38. 金属の鍵をナイフとして使用するアイデア
# 鍵をナイフとして使用するのは、その形状がナイフの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 39. 金属の鍵をコーラとして使用するアイデア
# 鍵をコーラとして使用するアイデアは、意味が不明瞭であり、実際の実現可能性を考慮すると非常にユニークで意外性のあるアイデアです。
# {"novelty":95}
#
# 40. 金属の鍵をハサミとして使用するアイデア
# 鍵をハサミとして使用するのは、その形状がハサミの代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 41. 金属の鍵をフォーチュンクッキーの中身として使用するアイデア
# 鍵をフォーチュンクッキーの中身として使用するのは、非常にユニークで意外性のあるアイデアですが、実用性に欠ける可能性があります。
# {"novelty":85}
#
# 42. 金属の鍵を彫刻刀として使用するアイデア
# 鍵を彫刻刀として使用するのは、その形状が彫刻刀の代用品として機能するため、創造的ですが、非常に特異なアイデアではありません。
# {"novelty":50}
#
# 43. 金属の鍵をスコップとして使用するアイデア
# 鍵をスコップとして使用するのは、その形状がスコップの代用品として機能することは難しいため、非常にユニークで意外性のあるアイデアです。
# {"novelty":70}
#
# 44. 金属の鍵をドアとして使用するアイデア
# 鍵をドアとして使用するアイデアは、実現可能性や意味合いが非常に不明瞭であり、非常にユニークで意外性のあるアイデアです。
# {"novelty":90}
#
# 45'''
# Error: Unexpected number of lines for item 44.
# Retrying request 22 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 38 of 90
# Request 39 of 90
# Request 40 of 90
# Request 41 of 90
# Request 42 of 90
# Request 43 of 90
# Request 44 of 90
# Request 45 of 90
# Request 46 of 90
# Request 47 of 90
# Request 48 of 90
# Request 49 of 90
# Request 50 of 90
# Request 51 of 90
# Request 52 of 90
# Request 53 of 90
# Request 54 of 90
# Request 55 of 90
# Request 56 of 90
# Request 57 of 90
# Request 58 of 90
# Request 59 of 90
# Request 60 of 90
# Request 61 of 90
# Request 62 of 90
# Request 63 of 90
# Request 64 of 90
# Failed parse (chunk 0). Prompt:
# '''We aim to evaluate the creativity of ideas in an Alternative Uses Tests (AUT) based on specific criteria. Please rate our ideas, given below, in terms of their Novelty, which is defined as follows:
# Novelty: Rate the novelty of the idea on a scale of 1 to 100, with 1 being not novel at all and 100 being extremely novel. Consider how unique, original, or surprising the idea is, while disregarding its feasibility and value.
#
# Proceed as follows in your evaluation. Write 3 lines for each item in the list below. On the first line, write the item number and briefly describe the idea in your own words. On the second line, consider other unconventional uses of the item, including those listed, and compare the idea to these in terms of its Novelty. Finally, on the third line, provide your numeric rating as a json object of the form {"novelty":x}. Evaluate each idea in the order provided, leaving one empty line between evaluations. Do evaluate each of the 44 ideas below individually, even if there are repetitions.
#
# Our ideas are to use the item "虫眼鏡" in the following ways:
# 1. 集光する道具
# 2. 老眼鏡
# 3. 鏡
# 4. 水槽
# 5. 水没
# 6. 顕微鏡
# 7. 眼鏡
# 8. 焼き物
# 9. 着火
# 10. 交換
# 11. タバコのライター
# 12. 火起こし
# 13. メール
# 14. カレンダー
# 15. 防犯
# 16. ひっかく
# 17. 太陽の光を集めて火起こし
# 18. スプーン
# 19. 点火
# 20. めがね
# 21. 眼鏡にする
# 22. 防寒グッズ
# 23. 着火剤
# 24. ける
# 25. コンロ
# 26. 火起こし器
# 27. ライター
# 28. 栞
# 29. 残す
# 30. 万華鏡
# 31. インテリア
# 32. カーテン
# 33. 文鎮
# 34. 集光器
# 35. 望遠鏡
# 36. ハエたたき
# 37. プリズム
# 38. コンパス
# 39. 調理器具
# 40. 双眼鏡
# 41. 器
# 42. 火おこし
# 43. テレビ
# 44. 武器'''
# Response:
# '''1. 集光する道具としての使用
# 虫眼鏡を光を集める道具として使用するアイデアは、虫眼鏡の基本的な機能に基づいている。
# 他の非伝統的な使用法と比較しても、このアイデアは比較的一般的である。
# {"novelty":20}
#
# 2. 老眼鏡としての使用
# 虫眼鏡を老眼鏡として使用するアイデアは、視力補助という点で実用的だが、創造性は低い。
# 老眼鏡としての使用は、虫眼鏡の拡大機能を応用したものであり、非常に一般的な考え方である。
# {"novelty":15}
#
# 3. 鏡としての使用
# 虫眼鏡を鏡として使用するアイデアは、非常に基本的であり、他の多くのアイデアと比較しても新しさは低い。
# 虫眼鏡の反射機能を利用するという点では、他の非伝統的な使用法と比べても目新しさはない。
# {"novelty":10}
#
# 4. 水槽としての使用
# 虫眼鏡を水槽として使用するアイデアは、サイズや形状の面で実現が難しいが、創造性は高い。
# このような使用法は一般的ではなく、他の非伝統的な使用法と比較してもかなりユニークである。
# {"novelty":70}
#
# 5. 水没させる
# 虫眼鏡を水没させるというアイデアは、具体的な使用目的が不明であり、創造性を評価しにくい。
# 他の非伝統的な使用法と比較しても、このアイデアは特に目新しいわけではない。
# {"novelty":30}
#
# 6. 顕微鏡としての使用
# 虫眼鏡を顕微鏡として使用するアイデアは、拡大機能を応用したものであり、比較的一般的な考え方である。
# 他の非伝統的な使用法と比較しても、このアイデアはそれほど目新しくはない。
# {"novelty":25}
#
# 7. 眼鏡としての使用
# 虫眼鏡を眼鏡として使用するアイデアは、老眼鏡としての使用と似ており、創造性は低い。
# このアイデアは、虫眼鏡の基本的な機能を応用したものであり、非常に一般的である。
# {"novelty":15}
#
# 8. 焼き物としての使用
# 虫眼鏡を焼き物として使用するアイデアは、光を集めて高温を生み出す機能を応用したものであり、創造性がある。
# 他の非伝統的な使用法と比較しても、このアイデアは比較的ユニークである。
# {"novelty":60}
#
# 9. 着火としての使用
# 虫眼鏡を着火ツールとして使用するアイデアは、光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 10. 交換としての使用
# 虫眼鏡を交換の対象として使用するアイデアは、具体的な使用方法が不明であり、創造性を評価しにくい。
# 他の非伝統的な使用法と比較しても、このアイデアは特に目新しいわけではない。
# {"novelty":20}
#
# 11. タバコのライターとしての使用
# 虫眼鏡をタバコのライターとして使用するアイデアは、着火という機能を特定の用途に応用したものであり、創造性がある。
# 他の非伝統的な使用法と比較しても、このアイデアはややユニークである。
# {"novelty":50}
#
# 12. 火起こしとしての使用
# 虫眼鏡を火起こしツールとして使用するアイデアは、着火と同様に光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 13. メールとしての使用
# 虫眼鏡をメールとして使用するアイデアは、非常に抽象的であり、具体的な使用方法が想像しにくい。
# 他の非伝統的な使用法と比較しても、このアイデアは非常にユニークだが、実現可能性が低い。
# {"novelty":80}
#
# 14. カレンダーとしての使用
# 虫眼鏡をカレンダーとして使用するアイデアは、非常に抽象的であり、具体的な使用方法が想像しにくい。
# 他の非伝統的な使用法と比較しても、このアイデアは非常にユニークだが、実現可能性が低い。
# {"novelty":80}
#
# 15. 防犯としての使用
# 虫眼鏡を防犯ツールとして使用するアイデアは、非常にユニークであり、他の非伝統的な使用法と比較しても目新しい。
# このアイデアは、虫眼鏡の機能を非常に創造的に応用したものである。
# {"novelty":75}
#
# 16. ひっかくとしての使用
# 虫眼鏡をひっかくツールとして使用するアイデアは、非常に基本的であり、他の多くのアイデアと比較しても新しさは低い。
# この使用法は、虫眼鏡の物理的な特性を利用したものであり、目新しさはない。
# {"novelty":10}
#
# 17. 太陽の光を集めて火起こし
# 虫眼鏡を太陽の光を集めて火を起こすツールとして使用するアイデアは、着火や火起こしと同様に基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 18. スプーンとしての使用
# 虫眼鏡をスプーンとして使用するアイデアは、形状や材質の面で実現が難しいが、創造性は高い。
# このような使用法は一般的ではなく、他の非伝統的な使用法と比較してもかなりユニークである。
# {"novelty":65}
#
# 19. 点火としての使用
# 虫眼鏡を点火ツールとして使用するアイデアは、着火や火起こしと同様に光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 20. めがねとしての使用
# 虫眼鏡をめがねとして使用するアイデアは、老眼鏡や眼鏡としての使用と似ており、創造性は低い。
# このアイデアは、虫眼鏡の基本的な機能を応用したものであり、非常に一般的である。
# {"novelty":15}
#
# 21. 眼鏡にする
# 虫眼鏡を眼鏡にするアイデアは、老眼鏡やめがねとしての使用と似ており、創造性は低い。
# このアイデアは、虫眼鏡の基本的な機能を応用したものであり、非常に一般的である。
# {"novelty":15}
#
# 22. 防寒グッズとしての使用
# 虫眼鏡を防寒グッズとして使用するアイデアは、非常にユニークであり、他の非伝統的な使用法と比較しても目新しい。
# このアイデアは、虫眼鏡の機能を非常に創造的に応用したものであるが、実現可能性は低い。
# {"novelty":75}
#
# 23. 着火剤としての使用
# 虫眼鏡を着火剤として使用するアイデアは、着火や火起こしと同様に光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 24. けるとしての使用
# 虫眼鏡をけるツールとして使用するアイデアは、非常に基本的であり、他の多くのアイデアと比較しても新しさは低い。
# この使用法は、虫眼鏡の物理的な特性を利用したものであり、目新しさはない。
# {"novelty":10}
#
# 25. コンロとしての使用
# 虫眼鏡をコンロとして使用するアイデアは、光を集めて高温を生み出す機能を応用したものであり、創造性がある。
# 他の非伝統的な使用法と比較しても、このアイデアは比較的ユニークである。
# {"novelty":60}
#
# 26. 火起こし器としての使用
# 虫眼鏡を火起こし器として使用するアイデアは、着火や火起こしと同様に光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 27. ライターとしての使用
# 虫眼鏡をライターとして使用するアイデアは、着火や火起こしと同様に光を集めて火を起こすという基本的な機能に基づいている。
# この使用法は一般的な知識に基づくものであり、他の非伝統的な使用法と比較しても新しさは低い。
# {"novelty":30}
#
# 28. 栞としての使用
# 虫眼鏡を栞として使用するアイデアは、非常にユニークであり、他の非伝統的な使用法と比較しても目新しい。
# このアイデアは、虫眼鏡の機能を非常に創造的に応用したものである。
# {"novelty":70}
#
# 29. 残すとしての使用
# 虫眼鏡を残すというアイデアは、具体的な使用方法が不明であり、創造性を評価しにくい。
# 他の非伝統的な使用法と比較しても、このアイデアは特に目新しいわけではない。
# {"novelty":20}
#
# 30. 万華鏡としての使用
# 虫眼鏡を万華鏡として使用するアイデアは、光の屈折や反射を利用するという点で創造性がある。
# 他の非伝統的な使用法と比較しても、このアイデアは比較的ユニークである。
# {"novelty":65}
#
# 31. インテリアとしての使用
# 虫眼鏡をインテリアとして使用するアイデアは、非常にユニークであり、他の非伝統的な使用法と比較しても目新しい。
# このアイデアは、虫眼鏡の機能を非常に創造的に応用したものである。
# {"novelty":75}
#
# 32. カーテンとしての使用
# 虫眼鏡をカーテンとして使用するアイデアは、非常にユニークであり、他の非伝統的な使用法と比較しても目新しい。
# このアイデアは、虫眼鏡の機能を非常に創造的に応用したものであるが、実現可能性は低い。
# {"novelty":80}
#
# 33. 文鎮としての使用
# 虫眼鏡を文鎮として使用するアイデアは、非常に基本的であり、他の多くのアイデアと比較しても新しさは低い。
# この使用法は、虫眼鏡の物理的な特性を利用したものであり、目新しさはない。
# {"novelty":10}
#
# 34. 集光器としての使用
# 虫眼鏡を集光器として使用するアイデアは、光を集めるという基本的な機能に基づいている。
# 他の非伝統的な使用法と比較しても、このアイデアは比較的一般的である。
# {"novelty":20}
#
# 35. 望遠鏡としての使用
# 虫眼鏡を望遠鏡として使用するアイデアは、拡大機能を応用したものであり、創造性はあるが、一般的な考え方である。
# 他の非伝統的な使用法と比較しても、このアイデアはややユニークであるが、非常に一般的'''
# Error: Final line not valid JSON: 他の非伝統的な使用法と比較しても、このアイデアはややユニークであるが、非常に一般的
# Retrying request 49 with params {'n': 1, 'model': 'gpt-4-turbo-preview', 'temperature': 0.1}
# Request 65 of 90
# Request 66 of 90
# Request 67 of 90
# Request 68 of 90
# Request 69 of 90
# Request 70 of 90
# Request 71 of 90
# Request 72 of 90
# Request 73 of 90
# Request 74 of 90
# Request 75 of 90
# Request 76 of 90
# Request 77 of 90
# Request 78 of 90
# Request 79 of 90
# Request 80 of 90
# Request 81 of 90
# Request 82 of 90
# Request 83 of 90
# Request 84 of 90
# Request 85 of 90
# Request 86 of 90
# Request 87 of 90
# Request 88 of 90
# Request 89 of 90
# Request 90 of 90

# %%
source.to_excel(f'gpt-ratings/{fname}-turbo.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}-turbo.xlsx').set_index('Unnamed: 0')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.5578368972012572, pvalue=7.163357178719392e-101),
#  'feasibility': SignificanceResult(statistic=0.5948290227055469, pvalue=7.918310544395815e-118),
#  'value': SignificanceResult(statistic=0.18160282835740674, pvalue=1.604832713890343e-10)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (GPT{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='GPT')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

# plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (GPT)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='GPT')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# 塩
# 絵画
# 500000
# 1. 塩を使った絵画
# 塩を使ったアート作品はユニークであり、アート作品の価値は幅広いが、一般的に数万円から数百万円の範囲。
#
# 塩
# 絵
# 500000
# 16. 塩を絵として使用
# 塩を使ったアート作品はユニークであり、市場価値はあるが、アイテム1と同様に評価される。
#
# コルク
# 家の建築
# 500000
# 20. コルクを使った家の建築
# エコフレンドリーな建築材料としてのコルクは、持続可能な住宅市場で高い価値がある。
#
# レンガ
# 教室
# 10000000
# 18. レンガを教室として使用
# レンガを使った教室の建設は実用的で、市場価値は高い。
#
# ビニール袋
# 熱気球
# 1000000
# 9. ビニール袋を熱気球として使用するアイデア
# 熱気球は非常に高価で、数百万円以上の価値がある。
#
# レンガ
# 家
# 20000000
# 28. レンガを家として使用
# レンガを使った家の建設は実用的で、市場価値は非常に高い。
#
# レンガ
# 階段
# 500000
# 37. レンガを階段として使用
# レンガを使った階段は実用的で、市場価値は高い。
#
# レンガ
# トイレ
# 500000
# 42. レンガをトイレとして使用
# レンガを使ったトイレの建設は実用的で、市場価値は高い。
#
# コルク
# 住居
# 500000
# 40. コルクを使った住居
# エコフレンドリーな建築材料としてのコルクは、持続可能な住宅市場で高い価値がある。

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (GPT)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.22$, $p = 3.6e-12$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 23. As a refrigerator
# The idea of using a pen as a miniature refrigerator, perhaps in a dollhouse setting, is extremely imaginative.
# {"novelty":85}
