# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import s_1rxi as method
import plot_utils

# %%
chunk_size = 20

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size))
fname
# Out:
# 's_1r20i'

# %%
import rate
rate.setkey(1)

# %%
source = annotate.get_clean()

# %%
test = source[source['Question id'] == 0][:20]
test
# Out:
#      Participant #            Test_Date  Question id Question_en Answer
# 0               10  2021-12-23T04:04:27            0       Brick     粉砕  \
# 30              11  2022-01-18T06:31:14            0       Brick   フォーク
# 90              13  2022-01-27T06:54:05            0       Brick    火打石
# 120             14  2022-02-01T07:09:40            0       Brick     隠蔽
# 150             15  2022-02-03T03:16:53            0       Brick     延長
# 180             16  2022-02-17T02:55:14            0       Brick     寝具
# 210             17  2022-02-22T03:24:46            0       Brick     飲む
# 240             18  2022-02-24T04:21:52            0       Brick    積み木
# 300             20  2022-03-03T02:59:05            0       Brick    トイレ
# 330             21  2022-03-08T07:26:56            0       Brick     巻く
# 390             23  2022-03-17T02:57:51            0       Brick     殴る
# 450             25  2022-03-24T07:11:40            0       Brick      靴
# 510             27  2022-03-31T06:32:49            0       Brick      盾
# 570             29  2022-04-07T07:17:56            0       Brick  つけもの石
# 600             30  2022-04-12T03:29:12            0       Brick     筋肉
# 690             33  2022-04-21T06:04:00            0       Brick    かばん
# 750             35  2022-05-10T03:26:20            0       Brick     手帳
# 780             36  2022-05-19T03:52:15            0       Brick    絵の具
# 810             37  2022-05-26T03:25:19            0       Brick   ジェンガ
# 840             38  2022-05-31T07:21:32            0       Brick    漬物石
#
#      Novelty  Feasibility  Value  W_Novelty  L_Novelty  ...  NG_FEASIBILITY
# 0       1591         1609   1559          7          8  ...               0  \
# 30      1616         1576   1551          9          7  ...               0
# 90      1608         1585   1608          9          8  ...               0
# 120     1618         1585   1569          9          7  ...               0
# 150     1623         1576   1584         10          7  ...               0
# 180     1640         1548   1606         11          6  ...               1
# 210     1616         1496   1514          9          7  ...               4
# 240     1521         1638   1552          4         14  ...               0
# 300     1648         1585   1629         11          5  ...               1
# 330     1635         1528   1552         11          7  ...               1
# 390     1553         1616   1568          5         11  ...               0
# 450     1655         1575   1609         12          5  ...               0
# 510     1600         1607   1608          8          8  ...               0
# 570     1560         1631   1576          6         11  ...               1
# 600     1714         1538   1617         16          1  ...               3
# 690     1632         1567   1616         10          6  ...               0
# 750     1639         1551   1576         11          6  ...               1
# 780     1655         1584   1559         12          5  ...               0
# 810     1571         1592   1625          7         11  ...               1
# 840     1554         1663   1609          5         11  ...               0
#
#      NG_VALUE  English  Question  sample_for_novelty  sample_for_feasibility
# 0           5    Brick       レンガ               False                   False  \
# 30          9    Brick       レンガ               False                   False
# 90          6    Brick       レンガ               False                   False
# 120         6    Brick       レンガ               False                   False
# 150         3    Brick       レンガ               False                   False
# 180         6    Brick       レンガ               False                   False
# 210         4    Brick       レンガ               False                   False
# 240        11    Brick       レンガ               False                   False
# 300         5    Brick       レンガ               False                   False
# 330         7    Brick       レンガ               False                   False
# 390         9    Brick       レンガ               False                   False
# 450         7    Brick       レンガ               False                   False
# 510         4    Brick       レンガ               False                   False
# 570         8    Brick       レンガ               False                   False
# 600         9    Brick       レンガ               False                   False
# 690         7    Brick       レンガ               False                   False
# 750         6    Brick       レンガ               False                   False
# 780         8    Brick       レンガ               False                   False
# 810         5    Brick       レンガ               False                   False
# 840         3    Brick       レンガ               False                   False
#
#      sample_for_value novelty_transformed feasibility_transformed
# 0               False                  52                      52  \
# 30              False                  61                      40
# 90              False                  58                      43
# 120             False                  62                      43
# 150             False                  64                      40
# 180             False                  70                      29
# 210             False                  61                      10
# 240             False                  26                      63
# 300             False                  73                      43
# 330             False                  68                      22
# 390             False                  38                      55
# 450             False                  76                      39
# 510             False                  55                      51
# 570             False                  40                      60
# 600             False                  98                      26
# 690             False                  67                      36
# 750             False                  70                      30
# 780             False                  76                      43
# 810             False                  44                      46
# 840             False                  38                      72
#
#      value_transformed
# 0                   33
# 30                  29
# 90                  56
# 120                 37
# 150                 45
# 180                 55
# 210                 11
# 240                 29
# 300                 66
# 330                 29
# 390                 37
# 450                 56
# 510                 56
# 570                 41
# 600                 60
# 690                 60
# 750                 41
# 780                 33
# 810                 64
# 840                 56
#
# [20 rows x 25 columns]

# %%
await method.rate(test, chunk_size=chunk_size)
# Out:
# Request 1 of 3
# Request 2 of 3
# Request 3 of 3

# %%
for i, r in test.iterrows():
    print(r['novelty_raw'])
# Out:
# 1. Idea: Using a brick ("レンガ") as a crushed material ("粉砕").
# This idea involves crushing the brick into a fine powder. While this is not a common use, it is not entirely unique as bricks are often crushed for various purposes.
# {"novelty": 45}
# 2. Idea: Using a brick ("レンガ") as a fork ("フォーク").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a fork, making this idea quite novel.
# {"novelty": 80}
# 3. Idea: Using a brick ("レンガ") as a flint ("火打石").
# This idea involves using a brick to start a fire, similar to how flint is used. This is a somewhat unconventional use of a brick, but not entirely unique.
# {"novelty": 60}
# 4. Idea: Using a brick ("レンガ") for concealment ("隠蔽").
# This idea involves using a brick to hide or conceal something. This is not a common use for a brick, but it's not entirely unique either.
# {"novelty": 55}
# 5. Idea: Using a brick ("レンガ") for extension ("延長").
# This idea involves using a brick to extend or increase the length of something. This is a somewhat unconventional use of a brick, but not entirely unique.
# {"novelty": 58}
# 6. Idea: Using a brick ("レンガ") as bedding ("寝具").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as bedding, making this idea quite novel.
# {"novelty": 85}
# 7. Idea: Using a brick ("レンガ") as a drink ("飲む").
# This is an extremely novel idea as it's hard to imagine how a brick could be used as a drink. This idea is highly unique and original.
# {"novelty": 95}
# 8. Idea: Using a brick ("レンガ") as a building block ("積み木").
# This is a common use for a brick, making it not very novel.
# {"novelty": 20}
# 9. Idea: Using a brick ("レンガ") as a toilet ("トイレ").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a toilet, making this idea quite novel.
# {"novelty": 90}
# 10. Idea: Using a brick ("レンガ") as a wrap ("巻く").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a wrap, making this idea quite novel.
# {"novelty": 85}
# 11. Idea: Using a brick ("レンガ") as a weapon ("殴る").
# This is a somewhat unconventional use of a brick, but not entirely unique as bricks have been used as weapons in the past.
# {"novelty": 60}
# 12. Idea: Using a brick ("レンガ") as a shoe ("靴").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a shoe, making this idea quite novel.
# {"novelty": 90}
# 13. Idea: Using a brick ("レンガ") as a shield ("盾").
# This is a somewhat unconventional use of a brick, but not entirely unique as bricks have been used as shields in the past.
# {"novelty": 65}
# 14. Idea: Using a brick ("レンガ") as a pickling stone ("つけもの石").
# This is a somewhat unconventional use of a brick, but not entirely unique as bricks have been used as weights in pickling processes.
# {"novelty": 70}
# 15. Idea: Using a brick ("レンガ") as a muscle ("筋肉").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a muscle, making this idea quite novel.
# {"novelty": 90}
# 16. Idea: Using a brick ("レンガ") as a bag ("かばん").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a bag, making this idea quite novel.
# {"novelty": 85}
# 17. Idea: Using a brick ("レンガ") as a notebook ("手帳").
# This is a highly unusual use of a brick. It's hard to imagine how a brick could function as a notebook, making this idea quite novel.
# {"novelty": 90}
# 18. Idea: Using a brick ("レンガ") as paint ("絵の具").
# This idea involves using a crushed brick as a pigment for paint. While this is not a common use, it is not entirely unique as bricks have been used for pigments in the past.
# {"novelty": 70}
# 19. Idea: Using a brick ("レンガ") as a Jenga piece ("ジェンガ").
# This is a somewhat unconventional use of a brick, but not entirely unique as bricks have been used in similar stacking games.
# {"novelty": 65}
# 20. Idea: Using a brick ("レンガ") as a pickling stone ("漬物石").
# This is a somewhat unconventional use of a brick, but not entirely unique as bricks have been used as weights in pickling processes.
# {"novelty": 70}

# %%
# Shuffle, because GPT is a fucking dickhead and implicitly refuses to rate two similar adjacent answers (case in point: brick as 重石 and 文鎮)
source = source.sample(frac=1, random_state=8)

# %%
await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 243
# Request 2 of 243
# Request 3 of 243
# Request 4 of 243
# Request 5 of 243
# Request 6 of 243
# Request 7 of 243
# Request 8 of 243
# Request 9 of 243
# Request 10 of 243
# Request 11 of 243
# Request 12 of 243
# Request 13 of 243
# Request 14 of 243
# Request 15 of 243
# Request 16 of 243
# Request 17 of 243
# Request 18 of 243
# Request 19 of 243
# Request 20 of 243
# Request 21 of 243
# Request 22 of 243
# Request 23 of 243
# Request 24 of 243
# Request 25 of 243
# Request 26 of 243
# Request 27 of 243
# Request 28 of 243
# Request 29 of 243
# Request 30 of 243
# Request 31 of 243
# Request 32 of 243
# Request 33 of 243
# Request 34 of 243
# Request 35 of 243
# Request 36 of 243
# Request 37 of 243
# Request 38 of 243
# Request 39 of 243
# Request 40 of 243
# Request 41 of 243
# Request 42 of 243
# Request 43 of 243
# Request 44 of 243
# Request 45 of 243
# Request 46 of 243
# Request 47 of 243
# Request 48 of 243
# Request 49 of 243
# Request 50 of 243
# Request 51 of 243
# Request 52 of 243
# Request 53 of 243
# Request 54 of 243
# Request 55 of 243
# Request 56 of 243
# Request 57 of 243
# Request 58 of 243
# Request 59 of 243
# Request 60 of 243
# Request 61 of 243
# Request 62 of 243
# Request 63 of 243
# Request 64 of 243
# Request 65 of 243
# Request 66 of 243
# Request 67 of 243
# Request 68 of 243
# Request 69 of 243
# Request 70 of 243
# Request 71 of 243
# Request 72 of 243
# Request 73 of 243
# Request 74 of 243
# Request 75 of 243
# Request 76 of 243
# Request 77 of 243
# Request 78 of 243
# Request 79 of 243
# Request 80 of 243
# Request 81 of 243
# Request 82 of 243
# Request 83 of 243
# Request 84 of 243
# Request 85 of 243
# Request 86 of 243
# Request 87 of 243
# Request 88 of 243
# Request 89 of 243
# Request 90 of 243
# Request 91 of 243
# Request 92 of 243
# Request 93 of 243
# Request 94 of 243
# Request 95 of 243
# Request 96 of 243
# Request 97 of 243
# Request 98 of 243
# Request 99 of 243
# Request 100 of 243
# Request 101 of 243
# Request 102 of 243
# Request 103 of 243
# Request 104 of 243
# Request 105 of 243
# Request 106 of 243
# Request 107 of 243
# Request 108 of 243
# Request 109 of 243
# Request 110 of 243
# Request 111 of 243
# Request 112 of 243
# Request 113 of 243
# Request 114 of 243
# Request 115 of 243
# Request 116 of 243
# Request 117 of 243
# Request 118 of 243
# Request 119 of 243
# Request 120 of 243
# Request 121 of 243
# Request 122 of 243
# Request 123 of 243
# Request 124 of 243
# Request 125 of 243
# Request 126 of 243
# Request 127 of 243
# Request 128 of 243
# Request 129 of 243
# Request 130 of 243
# Request 131 of 243
# Request 132 of 243
# Request 133 of 243
# Request 134 of 243
# Request 135 of 243
# Request 136 of 243
# Request 137 of 243
# Request 138 of 243
# Request 139 of 243
# Request 140 of 243
# Request 141 of 243
# Request 142 of 243
# Request 143 of 243
# Request 144 of 243
# Request 145 of 243
# Request 146 of 243
# Request 147 of 243
# Request 148 of 243
# Request 149 of 243
# Request 150 of 243
# Request 151 of 243
# Request 152 of 243
# Request 153 of 243
# Request 154 of 243
# Request 155 of 243
# Request 156 of 243
# Request 157 of 243
# Request 158 of 243
# Request 159 of 243
# Request 160 of 243
# Request 161 of 243
# Request 162 of 243
# Request 163 of 243
# Request 164 of 243
# Request 165 of 243
# Request 166 of 243
# Request 167 of 243
# Request 168 of 243
# Request 169 of 243
# Request 170 of 243
# Request 171 of 243
# Request 172 of 243
# Request 173 of 243
# Request 174 of 243
# Request 175 of 243
# Request 176 of 243
# Request 177 of 243
# Request 178 of 243
# Request 179 of 243
# Request 180 of 243
# Request 181 of 243
# Request 182 of 243
# Request 183 of 243
# Request 184 of 243
# Request 185 of 243
# Request 186 of 243
# Request 187 of 243
# Request 188 of 243
# Request 189 of 243
# Request 190 of 243
# Request 191 of 243
# Request 192 of 243
# Request 193 of 243
# Request 194 of 243
# Request 195 of 243
# Request 196 of 243
# Request 197 of 243
# Request 198 of 243
# Request 199 of 243
# Request 200 of 243
# Request 201 of 243
# Request 202 of 243
# Request 203 of 243
# Request 204 of 243
# Request 205 of 243
# Request 206 of 243
# Request 207 of 243
# Request 208 of 243
# Request 209 of 243
# Request 210 of 243
# Request 211 of 243
# Request 212 of 243
# Request 213 of 243
# Request 214 of 243
# Request 215 of 243
# Request 216 of 243
# Request 217 of 243
# Request 218 of 243
# Request 219 of 243
# Request 220 of 243
# Request 221 of 243
# Request 222 of 243
# Request 223 of 243
# Request 224 of 243
# Request 225 of 243
# Request 226 of 243
# Request 227 of 243
# Request 228 of 243
# Request 229 of 243
# Request 230 of 243
# Request 231 of 243
# Request 232 of 243
# Request 233 of 243
# Request 234 of 243
# Request 235 of 243
# Request 236 of 243
# Request 237 of 243
# Request 238 of 243
# Request 239 of 243
# Request 240 of 243
# Request 241 of 243
# Request 242 of 243
# Request 243 of 243
# Bad gateway. {"error":{"code":502,"message":"Bad gateway.","param":null,"type":"cf_bad_gateway"}} 502 {'error': {'code': 502, 'message': 'Bad gateway.', 'param': None, 'type': 'cf_bad_gateway'}} <CIMultiDictProxy('Date': 'Thu, 21 Sep 2023 06:29:21 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'same-origin', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Server': 'cloudflare', 'CF-RAY': '80a032301b80809c-NRT', 'alt-svc': 'h3=":443"; ma=86400')>
# Retrying in 5 s...

# %%
source.to_excel(f'gpt-ratings/{fname}.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}.xlsx').set_index('Unnamed: 0')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.6194508615494355, pvalue=2.142847701128533e-130),
#  'feasibility': SignificanceResult(statistic=0.6064894735945706, pvalue=1.2137371884432311e-123),
#  'value': SignificanceResult(statistic=0.3622135111368523, pvalue=3.458501730036549e-39)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (GPT{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='GPT')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (GPT)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='GPT')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# 金属の鍵
# 造金
# 300000
# 1. 金属の鍵を造金として使用
# Existing products achieving the same purpose: Gold bars, gold coins. Their value varies greatly depending on the weight and purity of the gold, but a small gold bar can be worth several hundred thousand yen.
#
# 裁縫針
# 雇う
# 300000
# 1. 雇う
# Using a sewing needle as a hired worker.
# The value of a hired worker varies greatly, but the average monthly salary in Japan is around 300,000 JPY.
#
# トイレットペーパー
# パソコン
# 165000
# 6. Idea: Using toilet paper as a computer.
# Existing products: Computers range from 30000 to 300000 JPY.
#
# ストロー
# 家の建築
# 500000000
# 3. Idea: Using a straw for building houses.
# The cost of building materials for a house can range from millions to billions of JPY.
#
# 段ボール箱
# 家
# 250000000
# 13. Idea: Using a cardboard box as a house.
# Existing houses range from 5,000,000 to 500,000,000 JPY.
#
# 歯ブラシ
# ペット
# 275000
# 4. ペット
# This idea suggests using a toothbrush as a pet.
# Pets, such as dogs or cats, can range from 50,000 to 500,000 JPY.
#
# ビニール袋
# 熱気球
# 1000000
# 9. 熱気球
# Using a plastic bag as a hot air balloon.
# Hot air balloons in Japan can cost millions of yen.
#
# ケチャップ
# 道路
# 1000000
# 13. Idea: Using ketchup as a road.
# Existing products: Road construction is expensive, ranging from millions to billions of JPY.
#
# ボールペン
# 冷蔵庫
# 115000
# 3. Refrigerator
# A real refrigerator can cost from 30,000 to 200,000 JPY.
#
# ビニール袋
# 自動車
# 10000000
# 11. 自動車
# Using a plastic bag as a car.
# Cars in Japan can range from 1,000,000 to 10,000,000 yen.
#
# ビニール袋
# 群馬
# 1000000
# 12. 群馬
# Using a plastic bag as a horse (Gunma is a horse breed in Japan).
# Horses in Japan can cost millions of yen.
#
# レンガ
# 家
# 30000000
# 8. Idea: Using a brick to build a house
# Existing houses are priced around 10,000,000 to 50,000,000 JPY.
#
# ビニール袋
# 家
# 10000000
# 16. 家
# Using a plastic bag as a house.
# Houses in Japan can cost millions of yen.
#
# レンガ
# 階段
# 125000
# 17. Idea: Using a brick as a staircase
# Existing staircases are priced around 50,000 to 200,000 JPY.
#
# コルク
# 住居
# 5005000
# 20. Idea: Using cork as a dwelling
# Dwellings in Japan can range from 100,000 to 10,000,000 yen depending on the size and location.

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (GPT)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.35$, $p = 3.1e-35$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 3. Using a ballpoint pen as a refrigerator
# This idea is extremely novel, as it is hard to imagine how a pen could function as a refrigerator. This is a very original and surprising use of a pen.
# {"novelty": 95}
