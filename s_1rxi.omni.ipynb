# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import s_1rxi as method
import plot_utils

# %%
chunk_size = 20

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size)) + '-omni'
fname
# Out:
# 's_1r20i-omni'

# %%
import rate
rate.setkey(1,'gpt')
rate.model = 'gpt-4o'

# %%
source = annotate.get_clean()

# %%
source = source.sample(frac=1, random_state=8)

# %%
requests = await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 243
# Request 2 of 243
# Request 3 of 243
# Request 4 of 243
# Request 5 of 243
# Request 6 of 243
# Request 7 of 243
# Request 8 of 243
# Request 9 of 243
# Request 10 of 243
# Request 11 of 243
# Request 12 of 243
# Request 13 of 243
# Request 14 of 243
# Request 15 of 243
# Request 16 of 243
# Request 17 of 243
# Request 18 of 243
# Request 19 of 243
# Request 20 of 243
# Request 21 of 243
# Request 22 of 243
# Request 23 of 243
# Request 24 of 243
# Request 25 of 243
# Request 26 of 243
# Request 27 of 243
# Request 28 of 243
# Request 29 of 243
# Request 30 of 243
# Request 31 of 243
# Request 32 of 243
# Request 33 of 243
# Request 34 of 243
# Request 35 of 243
# Request 36 of 243
# Request 37 of 243
# Request 38 of 243
# Request 39 of 243
# Request 40 of 243
# Request 41 of 243
# Request 42 of 243
# Request 43 of 243
# Request 44 of 243
# Request 45 of 243
# Request 46 of 243
# Request 47 of 243
# Request 48 of 243
# Request 49 of 243
# Request 50 of 243
# Request 51 of 243
# Request 52 of 243
# Request 53 of 243
# Request 54 of 243
# Request 55 of 243
# Request 56 of 243
# Request 57 of 243
# Request 58 of 243
# Request 59 of 243
# Request 60 of 243
# Request 61 of 243
# Request 62 of 243
# Request 63 of 243
# Request 64 of 243
# Request 65 of 243
# Request 66 of 243
# Request 67 of 243
# Request 68 of 243
# Request 69 of 243
# Request 70 of 243
# Request 71 of 243
# Request 72 of 243
# Request 73 of 243
# Request 74 of 243
# Request 75 of 243
# Request 76 of 243
# Request 77 of 243
# Request 78 of 243
# Request 79 of 243
# Request 80 of 243
# Request 81 of 243
# Request 82 of 243
# Request 83 of 243
# Request 84 of 243
# Request 85 of 243
# Request 86 of 243
# Request 87 of 243
# Request 88 of 243
# Request 89 of 243
# Request 90 of 243
# Request 91 of 243
# Request 92 of 243
# Request 93 of 243
# Request 94 of 243
# Request 95 of 243
# Request 96 of 243
# Request 97 of 243
# Request 98 of 243
# Request 99 of 243
# Request 100 of 243
# Request 101 of 243
# Request 102 of 243
# Request 103 of 243
# Request 104 of 243
# Request 105 of 243
# Request 106 of 243
# Request 107 of 243
# Request 108 of 243
# Request 109 of 243
# Request 110 of 243
# Request 111 of 243
# Request 112 of 243
# Request 113 of 243
# Request 114 of 243
# Request 115 of 243
# Request 116 of 243
# Request 117 of 243
# Request 118 of 243
# Request 119 of 243
# Request 120 of 243
# Request 121 of 243
# Request 122 of 243
# Request 123 of 243
# Request 124 of 243
# Request 125 of 243
# Request 126 of 243
# Request 127 of 243
# Request 128 of 243
# Request 129 of 243
# Request 130 of 243
# Request 131 of 243
# Request 132 of 243
# Request 133 of 243
# Request 134 of 243
# Request 135 of 243
# Request 136 of 243
# Request 137 of 243
# Request 138 of 243
# Request 139 of 243
# Request 140 of 243
# Request 141 of 243
# Request 142 of 243
# Request 143 of 243
# Request 144 of 243
# Request 145 of 243
# Request 146 of 243
# Request 147 of 243
# Request 148 of 243
# Request 149 of 243
# Request 150 of 243
# Request 151 of 243
# Request 152 of 243
# Request 153 of 243
# Request 154 of 243
# Request 155 of 243
# Request 156 of 243
# Request 157 of 243
# Request 158 of 243
# Request 159 of 243
# Request 160 of 243
# Request 161 of 243
# Request 162 of 243
# Request 163 of 243
# Request 164 of 243
# Request 165 of 243
# Request 166 of 243
# Request 167 of 243
# Request 168 of 243
# Request 169 of 243
# Request 170 of 243
# Request 171 of 243
# Request 172 of 243
# Request 173 of 243
# Request 174 of 243
# Request 175 of 243
# Request 176 of 243
# Request 177 of 243
# Request 178 of 243
# Request 179 of 243
# Request 180 of 243
# Request 181 of 243
# Request 182 of 243
# Request 183 of 243
# Request 184 of 243
# Request 185 of 243
# Request 186 of 243
# Request 187 of 243
# Request 188 of 243
# Request 189 of 243
# Request 190 of 243
# Request 191 of 243
# Request 192 of 243
# Request 193 of 243
# Request 194 of 243
# Request 195 of 243
# Request 196 of 243
# Request 197 of 243
# Request 198 of 243
# Request 199 of 243
# Request 200 of 243
# Request 201 of 243
# Request 202 of 243
# Request 203 of 243
# Request 204 of 243
# Request 205 of 243
# Request 206 of 243
# Request 207 of 243
# Request 208 of 243
# Request 209 of 243
# Request 210 of 243
# Request 211 of 243
# Request 212 of 243
# Request 213 of 243
# Request 214 of 243
# Request 215 of 243
# Request 216 of 243
# Request 217 of 243
# Request 218 of 243
# Request 219 of 243
# Request 220 of 243
# Request 221 of 243
# Request 222 of 243
# Request 223 of 243
# Request 224 of 243
# Request 225 of 243
# Request 226 of 243
# Request 227 of 243
# Request 228 of 243
# Request 229 of 243
# Request 230 of 243
# Request 231 of 243
# Request 232 of 243
# Request 233 of 243
# Request 234 of 243
# Request 235 of 243
# Request 236 of 243
# Request 237 of 243
# Request 238 of 243
# Request 239 of 243
# Request 240 of 243
# Request 241 of 243
# Request 242 of 243
# Request 243 of 243

# %%
failed = method.process(requests)

# %%
source.to_excel(f'gpt-ratings/{fname}.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}.xlsx').set_index('Unnamed: 0')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.6158073793997455, pvalue=1.8247195667077528e-128),
#  'feasibility': SignificanceResult(statistic=0.6489376005677744, pvalue=5.308713463745898e-147),
#  'value': SignificanceResult(statistic=0.21178220641884665, pvalue=7.391093106318274e-14)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (GPT-4o{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='GPT-4o')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

# plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (GPT-4o)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='GPT-4o')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# 木の箸
# パソコン
# 125000
# 2. パソコン
# A computer is a high-value item, with prices ranging from 50,000 to over 200,000 JPY depending on specifications and brand.
#
# ストロー
# 家の建築
# 1000000
# 3. 家の建築
# Using straws to construct a house.
# Building materials for houses are extremely expensive, often in the millions of JPY.
#
# ボールペン
# 家
# 1000000
# 8. 家
# Using ballpoint pens to build a house.
# Building materials for a house are extremely expensive, often in the millions of JPY.
#
# 輪ゴム
# 家
# 1000000
# 11. 家: Using a rubber band to build a house.
# Existing building materials are valued in the range of millions of JPY.
#
# 新聞
# エレベーター
# 1000000
# 12. エレベーター
# Using a newspaper as an elevator.
# Elevators are extremely expensive, typically around 1,000,000-5,000,000 JPY.
#
# トイレットペーパー
# 家の建築
# 10000000
# 15. House construction.
# Building materials for a house are extremely expensive, ranging from millions of JPY.
#
# レンガ
# 家
# 30000000
# 8. 家
# Using bricks to build a house.
# The cost of building a house can range from 10,000,000 to 50,000,000 JPY.

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (GPT-4o)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.19$, $p = 9.2e-11$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 3. Using the pen as a refrigerator.
# This idea is extremely novel and surprising, as it is highly unconventional and imaginative.
# {"novelty": 95}
