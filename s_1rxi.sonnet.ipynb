# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import annotate
import s_1rxi as method
import plot_utils

# %%
chunk_size = 20

# %%
fname = method.__file__.split('/')[-1][:-3].replace('x', str(chunk_size)) + '-sonnet'
fname
# Out:
# 's_1r20i-sonnet'

# %%
import rate
rate.setkey(0,'claude')

# %%
source = annotate.get_clean()

# %%
test = source[source['Question id'] == 0][:20]
test
# Out:
#      Participant #            Test_Date  Question id Question_en Answer
# 0               10  2021-12-23T04:04:27            0       Brick     粉砕  \
# 30              11  2022-01-18T06:31:14            0       Brick   フォーク
# 90              13  2022-01-27T06:54:05            0       Brick    火打石
# 120             14  2022-02-01T07:09:40            0       Brick     隠蔽
# 150             15  2022-02-03T03:16:53            0       Brick     延長
# 180             16  2022-02-17T02:55:14            0       Brick     寝具
# 210             17  2022-02-22T03:24:46            0       Brick     飲む
# 240             18  2022-02-24T04:21:52            0       Brick    積み木
# 300             20  2022-03-03T02:59:05            0       Brick    トイレ
# 330             21  2022-03-08T07:26:56            0       Brick     巻く
# 390             23  2022-03-17T02:57:51            0       Brick     殴る
# 450             25  2022-03-24T07:11:40            0       Brick      靴
# 510             27  2022-03-31T06:32:49            0       Brick      盾
# 570             29  2022-04-07T07:17:56            0       Brick  つけもの石
# 600             30  2022-04-12T03:29:12            0       Brick     筋肉
# 690             33  2022-04-21T06:04:00            0       Brick    かばん
# 750             35  2022-05-10T03:26:20            0       Brick     手帳
# 780             36  2022-05-19T03:52:15            0       Brick    絵の具
# 810             37  2022-05-26T03:25:19            0       Brick   ジェンガ
# 840             38  2022-05-31T07:21:32            0       Brick    漬物石
#
#      Novelty  Feasibility  Value  W_Novelty  L_Novelty  ...  NG_FEASIBILITY
# 0       1591         1609   1559          7          8  ...               0  \
# 30      1616         1576   1551          9          7  ...               0
# 90      1608         1585   1608          9          8  ...               0
# 120     1618         1585   1569          9          7  ...               0
# 150     1623         1576   1584         10          7  ...               0
# 180     1640         1548   1606         11          6  ...               1
# 210     1616         1496   1514          9          7  ...               4
# 240     1521         1638   1552          4         14  ...               0
# 300     1648         1585   1629         11          5  ...               1
# 330     1635         1528   1552         11          7  ...               1
# 390     1553         1616   1568          5         11  ...               0
# 450     1655         1575   1609         12          5  ...               0
# 510     1600         1607   1608          8          8  ...               0
# 570     1560         1631   1576          6         11  ...               1
# 600     1714         1538   1617         16          1  ...               3
# 690     1632         1567   1616         10          6  ...               0
# 750     1639         1551   1576         11          6  ...               1
# 780     1655         1584   1559         12          5  ...               0
# 810     1571         1592   1625          7         11  ...               1
# 840     1554         1663   1609          5         11  ...               0
#
#      NG_VALUE  English  Question  sample_for_novelty  sample_for_feasibility
# 0           5    Brick       レンガ               False                   False  \
# 30          9    Brick       レンガ               False                   False
# 90          6    Brick       レンガ               False                   False
# 120         6    Brick       レンガ               False                   False
# 150         3    Brick       レンガ               False                   False
# 180         6    Brick       レンガ               False                   False
# 210         4    Brick       レンガ               False                   False
# 240        11    Brick       レンガ               False                   False
# 300         5    Brick       レンガ               False                   False
# 330         7    Brick       レンガ               False                   False
# 390         9    Brick       レンガ               False                   False
# 450         7    Brick       レンガ               False                   False
# 510         4    Brick       レンガ               False                   False
# 570         8    Brick       レンガ               False                   False
# 600         9    Brick       レンガ               False                   False
# 690         7    Brick       レンガ               False                   False
# 750         6    Brick       レンガ               False                   False
# 780         8    Brick       レンガ               False                   False
# 810         5    Brick       レンガ               False                   False
# 840         3    Brick       レンガ               False                   False
#
#      sample_for_value novelty_transformed feasibility_transformed
# 0               False                  52                      52  \
# 30              False                  61                      40
# 90              False                  58                      43
# 120             False                  62                      43
# 150             False                  64                      40
# 180             False                  70                      29
# 210             False                  61                      10
# 240             False                  26                      63
# 300             False                  73                      43
# 330             False                  68                      22
# 390             False                  38                      55
# 450             False                  76                      39
# 510             False                  55                      51
# 570             False                  40                      60
# 600             False                  98                      26
# 690             False                  67                      36
# 750             False                  70                      30
# 780             False                  76                      43
# 810             False                  44                      46
# 840             False                  38                      72
#
#      value_transformed
# 0                   33
# 30                  29
# 90                  56
# 120                 37
# 150                 45
# 180                 55
# 210                 11
# 240                 29
# 300                 66
# 330                 29
# 390                 37
# 450                 56
# 510                 56
# 570                 41
# 600                 60
# 690                 60
# 750                 41
# 780                 33
# 810                 64
# 840                 56
#
# [20 rows x 25 columns]

# %%
requests = await method.rate(test, chunk_size=chunk_size)
# Out:
# Request 1 of 3
# Request 2 of 3
# Request 3 of 3

# %%
method.process(requests)

# %%
test
# Out:
#      Participant #            Test_Date  Question id Question_en Answer
# 0               10  2021-12-23T04:04:27            0       Brick     粉砕  \
# 30              11  2022-01-18T06:31:14            0       Brick   フォーク
# 90              13  2022-01-27T06:54:05            0       Brick    火打石
# 120             14  2022-02-01T07:09:40            0       Brick     隠蔽
# 150             15  2022-02-03T03:16:53            0       Brick     延長
# 180             16  2022-02-17T02:55:14            0       Brick     寝具
# 210             17  2022-02-22T03:24:46            0       Brick     飲む
# 240             18  2022-02-24T04:21:52            0       Brick    積み木
# 300             20  2022-03-03T02:59:05            0       Brick    トイレ
# 330             21  2022-03-08T07:26:56            0       Brick     巻く
# 390             23  2022-03-17T02:57:51            0       Brick     殴る
# 450             25  2022-03-24T07:11:40            0       Brick      靴
# 510             27  2022-03-31T06:32:49            0       Brick      盾
# 570             29  2022-04-07T07:17:56            0       Brick  つけもの石
# 600             30  2022-04-12T03:29:12            0       Brick     筋肉
# 690             33  2022-04-21T06:04:00            0       Brick    かばん
# 750             35  2022-05-10T03:26:20            0       Brick     手帳
# 780             36  2022-05-19T03:52:15            0       Brick    絵の具
# 810             37  2022-05-26T03:25:19            0       Brick   ジェンガ
# 840             38  2022-05-31T07:21:32            0       Brick    漬物石
#
#      Novelty  Feasibility  Value  W_Novelty  L_Novelty  ...
# 0       1591         1609   1559          7          8  ...  \
# 30      1616         1576   1551          9          7  ...
# 90      1608         1585   1608          9          8  ...
# 120     1618         1585   1569          9          7  ...
# 150     1623         1576   1584         10          7  ...
# 180     1640         1548   1606         11          6  ...
# 210     1616         1496   1514          9          7  ...
# 240     1521         1638   1552          4         14  ...
# 300     1648         1585   1629         11          5  ...
# 330     1635         1528   1552         11          7  ...
# 390     1553         1616   1568          5         11  ...
# 450     1655         1575   1609         12          5  ...
# 510     1600         1607   1608          8          8  ...
# 570     1560         1631   1576          6         11  ...
# 600     1714         1538   1617         16          1  ...
# 690     1632         1567   1616         10          6  ...
# 750     1639         1551   1576         11          6  ...
# 780     1655         1584   1559         12          5  ...
# 810     1571         1592   1625          7         11  ...
# 840     1554         1663   1609          5         11  ...
#
#                                    novelty_explanation  novelty
# 0    Compared to other unconventional uses, pulveri...     35.0  \
# 30   Using a brick as a fork is quite unusual and c...     65.0
# 90   While using a brick as a flint for starting fi...     55.0
# 120  Using a brick for concealment is somewhat comm...     40.0
# 150  The idea of using a brick as an extension is v...     60.0
# 180  Using a brick as bedding is highly unconventio...     75.0
# 210  The notion of drinking a brick is highly unusu...     80.0
# 240  Using bricks as building blocks is their prima...     20.0
# 300  The concept of using a brick as a toilet is hi...     78.0
# 330  The idea of wrapping something with a brick is...     70.0
# 390  Using a brick as a weapon or to hit something ...     30.0
# 450  The concept of using a brick as a shoe is high...     75.0
# 510  While using a brick as a shield is unconventio...     50.0
# 570  Using a brick as a weight for pickling is some...     60.0
# 600  The idea of using a brick as a muscle is highl...     85.0
# 690  Conceptualizing a brick as a bag is highly cre...     80.0
# 750  Using a brick as a notebook is a novel idea, a...     75.0
# 780  The concept of using a brick as paint is highl...     85.0
# 810  Using bricks for a Jenga-like game is somewhat...     55.0
# 840  This use is similar to the earlier "つけもの石" ide...     60.0
#
#                                        feasibility_raw
# 0    1. Pulverizing: Using a brick to grind or crus...  \
# 30   2. Fork: Using a brick as a utensil for eating...
# 90   3. Flint: Using a brick to create sparks for s...
# 120  4. Concealment: Using a brick to hide objects....
# 150  5. Extension: Using a brick to extend or prop ...
# 180  6. Bedding: Using bricks as part of a sleeping...
# 210  7. Drinking: Using a brick as a drinking vesse...
# 240  8. Building blocks: Using bricks as toys for c...
# 300  9. Toilet: Using a brick as part of a toilet s...
# 330  10. Wrapping: Using a brick to wrap or cover o...
# 390  11. Hitting: Using a brick as a weapon or tool...
# 450  12. Shoes: Using bricks as footwear.\nFeasibil...
# 510  13. Shield: Using a brick for protection or de...
# 570  14. Pickling stone: Using a brick to weigh dow...
# 600  15. Muscle: Using a brick for muscle-related p...
# 690  16. Bag: Using a brick as a container or carry...
# 750  17. Notebook: Using a brick as a writing or no...
# 780  18. Paint: Using a brick as a source of pigmen...
# 810  19. Jenga: Using bricks to play a Jenga-like s...
# 840  20. Pickling stone: Using a brick to weigh dow...
#
#                           feasibility_idea_explanation
# 0    1. Pulverizing: Using a brick to grind or crus...  \
# 30     2. Fork: Using a brick as a utensil for eating.
# 90   3. Flint: Using a brick to create sparks for s...
# 120     4. Concealment: Using a brick to hide objects.
# 150  5. Extension: Using a brick to extend or prop ...
# 180  6. Bedding: Using bricks as part of a sleeping...
# 210   7. Drinking: Using a brick as a drinking vessel.
# 240  8. Building blocks: Using bricks as toys for c...
# 300  9. Toilet: Using a brick as part of a toilet s...
# 330  10. Wrapping: Using a brick to wrap or cover o...
# 390  11. Hitting: Using a brick as a weapon or tool...
# 450               12. Shoes: Using bricks as footwear.
# 510  13. Shield: Using a brick for protection or de...
# 570  14. Pickling stone: Using a brick to weigh dow...
# 600  15. Muscle: Using a brick for muscle-related p...
# 690  16. Bag: Using a brick as a container or carry...
# 750  17. Notebook: Using a brick as a writing or no...
# 780  18. Paint: Using a brick as a source of pigmen...
# 810  19. Jenga: Using bricks to play a Jenga-like s...
# 840  20. Pickling stone: Using a brick to weigh dow...
#
#                                feasibility_explanation  feasibility
# 0    Feasibility is high as bricks are hard and can...         85.0  \
# 30   Feasibility is very low due to its shape, weig...          5.0
# 90   Feasibility is moderate as bricks can create s...         40.0
# 120  Feasibility is moderate as bricks can be hollo...         60.0
# 150  Feasibility is high as bricks are sturdy and c...         80.0
# 180  Feasibility is low due to discomfort and poten...         15.0
# 210  Feasibility is extremely low due to its porous...          3.0
# 240  Feasibility is high as bricks are naturally su...         85.0
# 300  Feasibility is low due to sanitation issues an...         10.0
# 330  Feasibility is very low due to the brick's rig...          5.0
# 390  Feasibility is high as bricks are naturally su...         75.0
# 450  Feasibility is extremely low due to discomfort...          2.0
# 510  Feasibility is moderate as bricks can block so...         50.0
# 570  Feasibility is high as bricks are heavy and no...         80.0
# 600  Feasibility is high as bricks can be used as w...         75.0
# 690  Feasibility is very low due to its solid natur...          5.0
# 750  Feasibility is low due to its rough surface an...         15.0
# 780  Feasibility is moderate as brick dust can be u...         45.0
# 810  Feasibility is high as bricks are well-suited ...         85.0
# 840  Feasibility is high as bricks are heavy and no...         80.0
#
#                                              value_raw
# 0    1. Pulverizing the brick into powder\nExisting...  \
# 30   2. Using a brick as a fork\nExisting unconvent...
# 90   3. Using a brick as a flint for starting fires...
# 120  4. Using a brick for concealment or hiding obj...
# 150  5. Using a brick as an extension or spacer\nEx...
# 180  6. Using a brick as bedding or a pillow\nUncon...
# 210  7. Drinking from a brick (presumably after hol...
# 240  8. Using bricks as building blocks\nExisting b...
# 300  9. Using a brick as a toilet (presumably as a ...
# 330  10. Wrapping something around a brick\nDecorat...
# 390  11. Using a brick as a weapon to hit with\nSel...
# 450  12. Using a brick as a shoe\nUnconventional fo...
# 510  13. Using a brick as a shield\nProtective gear...
# 570  14. Using a brick as a weight for pickling veg...
# 600  15. Using a brick for muscle training\nSimple ...
# 690  16. Using a brick as a bag\nUnconventional or ...
# 750  17. Using a brick as a notebook\nNovelty or ar...
# 780  18. Using a brick as a paint palette\nArtist t...
# 810  19. Using bricks to play a Jenga-like game\nEx...
# 840  20. Using a brick as a pickling weight\nTradit...
#
#                                 value_idea_explanation
# 0                 1. Pulverizing the brick into powder  \
# 30                          2. Using a brick as a fork
# 90      3. Using a brick as a flint for starting fires
# 120  4. Using a brick for concealment or hiding obj...
# 150         5. Using a brick as an extension or spacer
# 180            6. Using a brick as bedding or a pillow
# 210  7. Drinking from a brick (presumably after hol...
# 240                 8. Using bricks as building blocks
# 300  9. Using a brick as a toilet (presumably as a ...
# 330              10. Wrapping something around a brick
# 390          11. Using a brick as a weapon to hit with
# 450                        12. Using a brick as a shoe
# 510                      13. Using a brick as a shield
# 570  14. Using a brick as a weight for pickling veg...
# 600              15. Using a brick for muscle training
# 690                         16. Using a brick as a bag
# 750                    17. Using a brick as a notebook
# 780               18. Using a brick as a paint palette
# 810         19. Using bricks to play a Jenga-like game
# 840             20. Using a brick as a pickling weight
#
#                                      value_explanation  value
# 0    Existing products for pulverizing materials ca...   35.0
# 30   Existing unconventional or novelty cutlery ite...   32.0
# 90   Existing fire-starting tools typically cost be...   38.0
# 120  Existing diversion safes or hiding spots can c...   42.0
# 150  Existing spacers or extension tools can range ...   33.0
# 180  Unconventional pillows or bedding items can co...   45.0
# 210  Novelty drinking vessels can range from 1,000 ...   36.0
# 240  Existing building block sets can cost between ...   52.0
# 300  Portable or camping toilets can range from 5,0...   48.0
# 330  Decorative or functional wrapping materials ca...   31.0
# 390  Self-defense items or sports equipment can ran...   40.0
# 450  Unconventional footwear or art pieces can cost...   46.0
# 510  Protective gear or cosplay shields can range f...   50.0
# 570  Traditional pickling weights can cost between ...   37.0
# 600  Simple workout equipment can range from 2,000 ...   41.0
# 690  Unconventional or artistic bags can cost betwe...   47.0
# 750  Novelty or artistic stationery items can range...   39.0
# 780  Artist tools and palettes can cost between 1,0...   35.0
# 810  Existing block-stacking games can cost between...   44.0
# 840  Traditional pickling weights can cost between ...   37.0
#
# [20 rows x 37 columns]

# %%
for i, r in test.iterrows():
    print(r['novelty_raw'])
# Out:
# 1. 粉砕 (Pulverization)
# Compared to other unconventional uses, pulverizing a brick is relatively common and not particularly novel. It's often done for recycling or creating aggregate.
# {"novelty": 35}
# 2. フォーク (Fork)
# Using a brick as a fork is quite unusual and creative, as it's not a typical eating utensil shape. However, its impracticality somewhat limits its novelty.
# {"novelty": 65}
# 3. 火打石 (Flint)
# While using a brick as a flint for starting fires is unconventional, it's not entirely novel as other hard objects are sometimes used similarly.
# {"novelty": 55}
# 4. 隠蔽 (Concealment)
# Using a brick for concealment is somewhat common, especially in construction or landscaping. It's not particularly novel but has practical applications.
# {"novelty": 40}
# 5. 延長 (Extension)
# The idea of using a brick as an extension is vague but intriguing. It could be seen as novel depending on the specific application intended.
# {"novelty": 60}
# 6. 寝具 (Bedding)
# Using a brick as bedding is highly unconventional and surprising, though extremely impractical. Its novelty stems from its unexpected nature.
# {"novelty": 75}
# 7. 飲む (Drink)
# The notion of drinking a brick is highly unusual and surreal, making it a very novel idea despite its impossibility.
# {"novelty": 80}
# 8. 積み木 (Building blocks)
# Using bricks as building blocks is their primary purpose, so this idea lacks novelty despite its practicality.
# {"novelty": 20}
# 9. トイレ (Toilet)
# The concept of using a brick as a toilet is highly unconventional and surprising, contributing to its novelty despite its impracticality.
# {"novelty": 78}
# 10. 巻く (Wrap)
# The idea of wrapping something with a brick is unusual and creative, as bricks are typically rigid and not flexible.
# {"novelty": 70}
# 11. 殴る (Hit)
# Using a brick as a weapon or to hit something is not particularly novel, as it's a common improvised weapon in fiction and reality.
# {"novelty": 30}
# 12. 靴 (Shoe)
# The concept of using a brick as a shoe is highly unconventional and creative, offering a surprising contrast to typical footwear.
# {"novelty": 75}
# 13. 盾 (Shield)
# While using a brick as a shield is unconventional, it's not entirely novel as improvised shields made of various materials are sometimes seen.
# {"novelty": 50}
# 14. つけもの石 (Pickling weight)
# Using a brick as a weight for pickling is somewhat novel, as it repurposes the brick's weight in an unexpected context.
# {"novelty": 60}
# 15. 筋肉 (Muscle)
# The idea of using a brick as a muscle is highly abstract and unusual, contributing to its novelty despite its surreal nature.
# {"novelty": 85}
# 16. かばん (Bag)
# Conceptualizing a brick as a bag is highly creative and unexpected, offering a stark contrast to typical bag materials and designs.
# {"novelty": 80}
# 17. 手帳 (Notebook)
# Using a brick as a notebook is a novel idea, as it contrasts greatly with the typical properties of notebooks.
# {"novelty": 75}
# 18. 絵の具 (Paint)
# The concept of using a brick as paint is highly unconventional and creative, offering an interesting perspective on art materials.
# {"novelty": 85}
# 19. ジェンガ (Jenga)
# Using bricks for a Jenga-like game is somewhat novel, as it repurposes the brick's shape for entertainment, though similar to its building block use.
# {"novelty": 55}
# 20. 漬物石 (Pickling stone)
# This use is similar to the earlier "つけもの石" idea, repurposing the brick's weight for pickling. It's somewhat novel but not highly original.
# {"novelty": 60}

# %%
source = source.sample(frac=1, random_state=8)

# %%
requests = await method.rate(source, chunk_size=chunk_size)
# Out:
# Request 1 of 243
# Request 2 of 243
# Request 3 of 243
# Request 4 of 243
# Request 5 of 243
# Request 6 of 243
# Request 7 of 243
# Request 8 of 243
# Request 9 of 243
# Request 10 of 243
# Request 11 of 243
# Request 12 of 243
# Request 13 of 243
# Request 14 of 243
# Request 15 of 243
# Request 16 of 243
# Request 17 of 243
# Request 18 of 243
# Request 19 of 243
# Request 20 of 243
# Request 21 of 243
# Request 22 of 243
# Request 23 of 243
# Request 24 of 243
# Request 25 of 243
# Request 26 of 243
# Request 27 of 243
# Request 28 of 243
# Request 29 of 243
# Request 30 of 243
# Request 31 of 243
# Request 32 of 243
# Request 33 of 243
# Request 34 of 243
# Request 35 of 243
# Request 36 of 243
# Request 37 of 243
# Request 38 of 243
# Request 39 of 243
# Request 40 of 243
# Request 41 of 243
# Request 42 of 243
# Request 43 of 243
# Request 44 of 243
# Request 45 of 243
# Request 46 of 243
# Request 47 of 243
# Request 48 of 243
# Request 49 of 243
# Request 50 of 243
# Request 51 of 243
# Request 52 of 243
# Request 53 of 243
# Request 54 of 243
# Request 55 of 243
# Request 56 of 243
# Request 57 of 243
# Request 58 of 243
# Request 59 of 243
# Request 60 of 243
# Request 61 of 243
# Request 62 of 243
# Request 63 of 243
# Request 64 of 243
# Request 65 of 243
# Request 66 of 243
# Request 67 of 243
# Request 68 of 243
# Request 69 of 243
# Request 70 of 243
# Request 71 of 243
# Request 72 of 243
# Request 73 of 243
# Request 74 of 243
# Request 75 of 243
# Request 76 of 243
# Request 77 of 243
# Request 78 of 243
# Request 79 of 243
# Request 80 of 243
# Request 81 of 243
# Request 82 of 243
# Request 83 of 243
# Request 84 of 243
# Request 85 of 243
# Request 86 of 243
# Request 87 of 243
# Request 88 of 243
# Request 89 of 243
# Request 90 of 243
# Request 91 of 243
# Request 92 of 243
# Request 93 of 243
# Request 94 of 243
# Request 95 of 243
# Request 96 of 243
# Request 97 of 243
# Request 98 of 243
# Request 99 of 243
# Request 100 of 243
# Request 101 of 243
# Request 102 of 243
# Request 103 of 243
# Request 104 of 243
# Request 105 of 243
# Request 106 of 243
# Request 107 of 243
# Request 108 of 243
# Request 109 of 243
# Request 110 of 243
# Request 111 of 243
# Request 112 of 243
# Request 113 of 243
# Request 114 of 243
# Request 115 of 243
# Request 116 of 243
# Request 117 of 243
# Request 118 of 243
# Request 119 of 243
# Request 120 of 243
# Request 121 of 243
# Request 122 of 243
# Request 123 of 243
# Request 124 of 243
# Request 125 of 243
# Request 126 of 243
# Request 127 of 243
# Request 128 of 243
# Request 129 of 243
# Request 130 of 243
# Request 131 of 243
# Request 132 of 243
# Request 133 of 243
# Request 134 of 243
# Request 135 of 243
# Request 136 of 243
# Request 137 of 243
# Request 138 of 243
# Request 139 of 243
# Request 140 of 243
# Request 141 of 243
# Request 142 of 243
# Request 143 of 243
# Request 144 of 243
# Request 145 of 243
# Request 146 of 243
# Request 147 of 243
# Request 148 of 243
# Request 149 of 243
# Request 150 of 243
# Request 151 of 243
# Request 152 of 243
# Request 153 of 243
# Request 154 of 243
# Request 155 of 243
# Request 156 of 243
# Request 157 of 243
# Request 158 of 243
# Request 159 of 243
# Request 160 of 243
# Request 161 of 243
# Request 162 of 243
# Request 163 of 243
# Request 164 of 243
# Request 165 of 243
# Request 166 of 243
# Request 167 of 243
# Request 168 of 243
# Request 169 of 243
# Request 170 of 243
# Request 171 of 243
# Request 172 of 243
# Request 173 of 243
# Request 174 of 243
# Request 175 of 243
# Request 176 of 243
# Request 177 of 243
# Request 178 of 243
# Request 179 of 243
# Request 180 of 243
# Request 181 of 243
# Request 182 of 243
# Request 183 of 243
# Request 184 of 243
# Request 185 of 243
# Request 186 of 243
# Request 187 of 243
# Request 188 of 243
# Request 189 of 243
# Request 190 of 243
# Request 191 of 243
# Request 192 of 243
# Request 193 of 243
# Request 194 of 243
# Request 195 of 243
# Request 196 of 243
# Request 197 of 243
# Request 198 of 243
# Request 199 of 243
# Request 200 of 243
# Request 201 of 243
# Request 202 of 243
# Request 203 of 243
# Request 204 of 243
# Request 205 of 243
# Request 206 of 243
# Request 207 of 243
# Request 208 of 243
# Request 209 of 243
# Request 210 of 243
# Request 211 of 243
# Request 212 of 243
# Request 213 of 243
# Request 214 of 243
# Request 215 of 243
# Request 216 of 243
# Request 217 of 243
# Request 218 of 243
# Request 219 of 243
# Request 220 of 243
# Request 221 of 243
# Request 222 of 243
# Request 223 of 243
# Request 224 of 243
# Request 225 of 243
# Request 226 of 243
# Request 227 of 243
# Request 228 of 243
# Request 229 of 243
# Request 230 of 243
# Request 231 of 243
# Request 232 of 243
# Request 233 of 243
# Request 234 of 243
# Request 235 of 243
# Request 236 of 243
# Request 237 of 243
# Request 238 of 243
# Request 239 of 243
# Request 240 of 243
# Request 241 of 243
# Request 242 of 243
# Request 243 of 243

# %%
failed = method.process(requests)

# %%
source.to_excel(f'gpt-ratings/{fname}.xlsx')

# %%
source = pd.read_excel(f'gpt-ratings/{fname}.xlsx').set_index('Unnamed: 0')

# %%
corr = {key: stats.spearmanr(source[[key.capitalize(), key]]) for key in annotate.measures}
corr
# Out:
# {'novelty': SignificanceResult(statistic=0.600696487568641, pvalue=1.0064297257877795e-120),
#  'feasibility': SignificanceResult(statistic=0.5990828918872985, pvalue=6.384794623198796e-120),
#  'value': SignificanceResult(statistic=0.22546959590428467, pvalue=1.5038355305771742e-15)}

# %%
fig, axs = plt.subplots(2, 3, figsize=(7,4), layout='constrained', dpi=600)
for measure, ax in zip(annotate.measures, axs.T):
    Measure = measure.capitalize()
    if measure == 'value':
        mask = (source['value']>0) & (source['value']<100000)
        suffix = ', ¥'
        ax[0].semilogy(source[mask][Measure], source[mask][measure], 'ok', ms=.5)
    else:
        suffix = ''
        ax[0].plot(source[Measure], source[measure], 'ok', ms=.5)
    ax[0].set_xlabel(f'{Measure} (Elo)')
    ax[0].set_ylabel(f'{Measure} (Claude{suffix})')
    ax[0].set_title(Measure)
    if measure != 'value':
        ax[0].set_ylim(0,100)

    if measure != 'value':
        sns.histplot(source, x=f'{measure}_transformed', ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        sns.histplot(source, x=measure, ax=ax[1], kde=True, bins=25, binrange=(1,100), line_kws={'lw':1})
        ax[1].set_xlabel(Measure)

axs[1,2].plot([], label='Elo\n(1-100)')
axs[1,2].plot([], label='Claude')
axs[1,2].legend(loc='center left')
axs[1,2].set_xticks([])
axs[1,2].set_yticks([])

sns.despine()
sns.despine(ax=axs[1,2], bottom=True, left=True)

for i, ax in enumerate(axs.flatten()):
    if i < 5:
        plot_utils.label_panel(ax, i)

# plt.savefig(f'Figure_2.{fname}.pdf')

# %%
for key, c in corr.items():
    plt.figure(figsize=(4,4))
    sns.scatterplot(source, x=key.capitalize(), y=key)
    sns.despine()
    plt.xlabel(f'{key} (ELO)')
    plt.ylabel(f'{key} (Claude)')
    plt.title(f'{key}: $\\rho = {c.statistic:.2g}$, $p = {c.pvalue:.2g}$')

# %%
for key in ('novelty', 'feasibility'):
    fig, ax = plt.subplots(figsize=(4,2))
    sns.histplot(source, x=key, ax=ax, kde=True)
    sns.histplot(source, x=f'{key}_transformed', ax=ax, kde=True)
    sns.despine()
    plt.plot([], label='Claude')
    plt.plot([], label='ELO')
    plt.legend()

# %%
for idx, row in source[source['value']<0].iterrows():
    print(row['Question'], row['Answer'], row['value_explanation'], sep='\n', end='\n\n')

# %%
for idx, row in source[source['value'] > 100000].iterrows():
    print(row['Question'], row['Answer'], row['value'], row['value_idea_explanation'], row['value_explanation'], sep='\n', end='\n\n')
# Out:
# 傘
# パラシュート
# 600000
# 3. Using an umbrella as a parachute
# Actual parachutes cost between 200,000 to 1,000,000 yen
#
# コルク
# 家の建築
# 200000
# 20. Using cork for house construction
# Building materials vary greatly, but specialty eco-friendly materials can be quite expensive, ranging from 50,000-500,000 yen per unit
#
# 傘
# 乗り物
# 275000
# 19. Using an umbrella as a vehicle
# Small personal vehicles cost between 50,000 to 500,000 yen

# %%
mask = (source['value']>0) & (source['value']<100000)
vcorr = stats.spearmanr(source[mask][['Value', 'value']])
plt.figure(figsize=(4,4))
sns.scatterplot(source[mask], x='Value', y='value')
sns.despine()
plt.xlabel(f'value (ELO)')
plt.ylabel(f'value (Claude)')
plt.title(f'value: $\\rho = {vcorr.statistic:.2g}$, $p = {vcorr.pvalue:.2g}$')
# Out:
# Text(0.5, 1.0, 'value: $\\rho = 0.22$, $p = 1.2e-14$')

# %%
print(source[(source['Question']=='ボールペン')*(source['Answer']=='冷蔵庫')]['novelty_raw'].item())
# Out:
# 3. Using a ballpoint pen as a refrigerator
# This idea is highly novel and unexpected, as it suggests a drastic change in the pen's function and size.
# {"novelty": 89}
